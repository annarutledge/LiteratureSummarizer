# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
import time
import json
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape links to all books with summaries available

# %% [markdown]
# ## Testing - scrape first page (first 50 books)

# %%
#URL for main page with list of books summaries are available for

url = 'https://novelguide.com/novelguides'

# %%
#Check that request is successful

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
#Extract html

html = response.text

# %%
#Pass html to BeautifulSoup

soup = BeautifulSoup(html, 'lxml')

# %%
#List of table elements of page containing names and links for books
td_list = []
for tr in soup.find('table', {'class':'cols-2'}).find_all('tr')[1:]:
    td_list.append(tr.find_all('td'))

#find link in each table element and create list of links
book_links = []
for i in range(len(td_list)):
    for n in range(len(td_list[i])):
        if td_list[i][n].find('a') != None:  
            book_links.append('https://novelguide.com' + td_list[i][n].find('a')['href'])

book_links
# Out:
# ['https://novelguide.com/index.php/a-portrait-of-the-artist-as-a-young-man',
#  'https://novelguide.com/index.php/dubliners',
#  'https://novelguide.com/index.php/middlemarch',
#  'https://novelguide.com/index.php/the-diary-of-a-young-girl',
#  'https://novelguide.com/index.php/jurassic-park/index.html',
#  'https://novelguide.com/index.php/beowulf',
#  'https://novelguide.com/index.php/everything-is-illuminated',
#  'https://novelguide.com/index.php/inherit-the-wind/index.html',
#  'https://novelguide.com/index.php/go-tell-it-on-the-mountain',
#  'https://novelguide.com/index.php/a-farewell-to-arms',
#  'https://novelguide.com/index.php/the-age-of-innocence',
#  'https://novelguide.com/index.php/bonfire-of-the-vanities',
#  'https://novelguide.com/index.php/across-five-aprils',
#  'https://novelguide.com/index.php/the-color-purple',
#  'https://novelguide.com/index.php/the-assistant',
#  'https://novelguide.com/index.php/aristotles-politics/index.html',
#  'https://novelguide.com/index.php/the-count-of-monte-cristo',
#  'https://novelguide.com/index.php/a-midsummer-nights-dream',
#  'https://novelguide.com/index.php/silas-marner/index.html',
#  'https://novelguide.com/index.php/a-clockwork-orange',
#  'https://novelguide.com/index.php/benito-cereno/index',
#  'https://novelguide.com/index.php/seize-the-day',
#  'https://novelguide.com/index.php/the-brothers-karamazov',
#  'https://novelguide.com/index.php/i-know-why-the-caged-bird-sings',
#  'https://novelguide.com/index.php/ethan-frome/index.html',
#  'https://novelguide.com/index.php/loves-labours-lost/index.html',
#  'https://novelguide.com/index.php/bless-me-ultima/index.html',
#  'https://novelguide.com/index.php/war-and-peace/index.html',
#  'https://novelguide.com/index.php/breakfast-at-tiffanys',
#  'https://novelguide.com/index.php/a-walk-to-remember',
#  'https://novelguide.com/index.php/julius-caesar/index.html',
#  'https://novelguide.com/index.php/a-wrinkle-in-time',
#  'https://novelguide.com/index.php/the-adventures-of-tom-sawyer',
#  'https://novelguide.com/index.php/heart-of-darkness',
#  'https://novelguide.com/index.php/east-of-eden',
#  'https://novelguide.com/index.php/the-comedy-of-errors',
#  'https://novelguide.com/index.php/angelasashes',
#  'https://novelguide.com/index.php/parable-of-the-sower',
#  'https://novelguide.com/index.php/and-then-there-were-none/index.html',
#  'https://novelguide.com/index.php/oliver-twist/index.html',
#  'https://novelguide.com/index.php/pale-fire/index.html',
#  'https://novelguide.com/index.php/crito',
#  'https://novelguide.com/index.php/frankenstein',
#  'https://novelguide.com/index.php/maggie-a-girl-of-the-streets',
#  'https://novelguide.com/index.php/the-death-of-ivan-ilyich',
#  'https://novelguide.com/index.php/the-alchemist/index.html',
#  'https://novelguide.com/index.php/the-caine-mutiny',
#  'https://novelguide.com/index.php/madame-bovary/index',
#  'https://novelguide.com/index.php/gullivers-travels/index.html',
#  'https://novelguide.com/index.php/main-street/index.html']

# %%
#Number of links scraped

len(book_links)
# Out:
# 50

# %% [markdown]
# ## Scrape links to all books

# %%
#Starting with first page of books, create dictionary for each book with a corresponding title and link and add to list of book links
# iterate through each page of website (8 total) and repeat this process to collect all titles and links

next_page=1
book_links = []
url = 'https://novelguide.com/novelguides'
for page in range(8):
    response = requests.get(url)
    time.sleep(0.5)

    if response.status_code==200:
        html = response.text
        soup = BeautifulSoup(html, 'lxml')

        print(f'request {next_page} successful')

        td_list = []
        for tr in soup.find('table', {'class':'cols-2'}).find_all('tr')[1:]:
            td_list.append(tr.find_all('td'))

        for i in range(len(td_list)):
            for n in range(len(td_list[i])):
                if td_list[i][n].find('a') != None:
                    book = {}
                    book['title'] = td_list[i][n].find('a').text
                    book['link'] = 'https://novelguide.com' + td_list[i][n].find('a')['href']

                    book_links.append(book)   

        print(f'books from page {next_page} added')

        try:
            url = f'https://novelguide.com/novelguides?items_per_page=50&page={next_page}'
            next_page += 1

        except:
            print('Error scraping page')
# Out:
# request 1 successful
# books from page 1 added
# request 2 successful
# books from page 2 added
# request 3 successful
# books from page 3 added
# request 4 successful
# books from page 4 added
# request 5 successful
# books from page 5 added
# request 6 successful
# books from page 6 added
# request 7 successful
# books from page 7 added
# request 8 successful
# books from page 8 added

# %%
#Examine list of book links

book_links[:10]
# Out:
# [{'title': 'The Ambassadors',
#   'link': 'https://novelguide.com/the-ambassadors'},
#  {'title': 'Ivanhoe', 'link': 'https://novelguide.com/ivanhoe'},
#  {'title': 'Crito', 'link': 'https://novelguide.com/crito'},
#  {'title': 'Emma', 'link': 'https://novelguide.com/emma'},
#  {'title': 'The Assistant', 'link': 'https://novelguide.com/the-assistant'},
#  {'title': 'A Passage to India',
#   'link': 'https://novelguide.com/a-passage-to-india'},
#  {'title': 'Henry VIII',
#   'link': 'https://novelguide.com/henry-viii/index.html'},
#  {'title': 'Merry Wives of Windsor',
#   'link': 'https://novelguide.com/merry-wives-of-windsor'},
#  {'title': 'Antigone', 'link': 'https://novelguide.com/antigone-jean-anouilh'},
#  {'title': 'A Clockwork Orange',
#   'link': 'https://novelguide.com/a-clockwork-orange'}]

# %%
#Number of entries in book links list

len(book_links)
# Out:
# 382

# %% [markdown]
# ## Save book links to json file

# %%
with open('./data/working_data/book_summaries/book_links.json', 'w') as fp:
    json.dump(book_links, fp)

# %% [markdown]
# # Scrape links to all book summaries

# %% [markdown]
# ## Scrape links

# %%
#Read in dictionary of book links created in last step

book_links_df = pd.read_json('./data/working_data/book_summaries/book_links.json')
book_links_df.head()
# Out:
#              title                                    link
# 0  The Ambassadors  https://novelguide.com/the-ambassadors
# 1          Ivanhoe          https://novelguide.com/ivanhoe
# 2            Crito            https://novelguide.com/crito
# 3             Emma             https://novelguide.com/emma
# 4    The Assistant    https://novelguide.com/the-assistant

# %%
#Iterate through list of book links and create new list of dictionaries containing the title of a book and the links to all
# of the chapter summaries for this book

book_summary_links = []

for i in book_links_df.index:

    book = {}
    book['title'] = book_links_df.iloc[i]['title']
    book['summaries'] = []

    url = book_links_df.iloc[i]['link']
    response = requests.get(url)
    time.sleep(0.5)

    if response.status_code==200:
        html = response.text
        soup = BeautifulSoup(html, 'lxml')
            
        for li in soup.find('div', {'id':'mainWrapper'}).find('div', {'id':'header'}).find('div', {'id':'content_top_full'}).find('div', {'id':'block-booknavigation-3'}).find_all('li'):
            if 'summary' in li.find('a').text.lower():
                book['summaries'].append('https://novelguide.com' + li.find('a')['href'])
    book_summary_links.append(book)
    print(f'book {i} summary links added')
# Out:
# book 0 summary links added
# book 1 summary links added
# book 2 summary links added
# book 3 summary links added
# book 4 summary links added
# book 5 summary links added
# book 6 summary links added
# book 7 summary links added
# book 8 summary links added
# book 9 summary links added
# book 10 summary links added
# book 11 summary links added
# book 12 summary links added
# book 13 summary links added
# book 14 summary links added
# book 15 summary links added
# book 16 summary links added
# book 17 summary links added
# book 18 summary links added
# book 19 summary links added
# book 20 summary links added
# book 21 summary links added
# book 22 summary links added
# book 23 summary links added
# book 24 summary links added
# book 25 summary links added
# book 26 summary links added
# book 27 summary links added
# book 28 summary links added
# book 29 summary links added
# book 30 summary links added
# book 31 summary links added
# book 32 summary links added
# book 33 summary links added
# book 34 summary links added
# book 35 summary links added
# book 36 summary links added
# book 37 summary links added
# book 38 summary links added
# book 39 summary links added
# book 40 summary links added
# book 41 summary links added
# book 42 summary links added
# book 43 summary links added
# book 44 summary links added
# book 45 summary links added
# book 46 summary links added
# book 47 summary links added
# book 48 summary links added
# book 49 summary links added
# book 50 summary links added
# book 51 summary links added
# book 52 summary links added
# book 53 summary links added
# book 54 summary links added
# book 55 summary links added
# book 56 summary links added
# book 57 summary links added
# book 58 summary links added
# book 59 summary links added
# book 60 summary links added
# book 61 summary links added
# book 62 summary links added
# book 63 summary links added
# book 64 summary links added
# book 65 summary links added
# book 66 summary links added
# book 67 summary links added
# book 68 summary links added
# book 69 summary links added
# book 70 summary links added
# book 71 summary links added
# book 72 summary links added
# book 73 summary links added
# book 74 summary links added
# book 75 summary links added
# book 76 summary links added
# book 77 summary links added
# book 78 summary links added
# book 79 summary links added
# book 80 summary links added
# book 81 summary links added
# book 82 summary links added
# book 83 summary links added
# book 84 summary links added
# book 85 summary links added
# book 86 summary links added
# book 87 summary links added
# book 88 summary links added
# book 89 summary links added
# book 90 summary links added
# book 91 summary links added
# book 92 summary links added
# book 93 summary links added
# book 94 summary links added
# book 95 summary links added
# book 96 summary links added
# book 97 summary links added
# book 98 summary links added
# book 99 summary links added
# book 100 summary links added
# book 101 summary links added
# book 102 summary links added
# book 103 summary links added
# book 104 summary links added
# book 105 summary links added
# book 106 summary links added
# book 107 summary links added
# book 108 summary links added
# book 109 summary links added
# book 110 summary links added
# book 111 summary links added
# book 112 summary links added
# book 113 summary links added
# book 114 summary links added
# book 115 summary links added
# book 116 summary links added
# book 117 summary links added
# book 118 summary links added
# book 119 summary links added
# book 120 summary links added
# book 121 summary links added
# book 122 summary links added
# book 123 summary links added
# book 124 summary links added
# book 125 summary links added
# book 126 summary links added
# book 127 summary links added
# book 128 summary links added
# book 129 summary links added
# book 130 summary links added
# book 131 summary links added
# book 132 summary links added
# book 133 summary links added
# book 134 summary links added
# book 135 summary links added
# book 136 summary links added
# book 137 summary links added
# book 138 summary links added
# book 139 summary links added
# book 140 summary links added
# book 141 summary links added
# book 142 summary links added
# book 143 summary links added
# book 144 summary links added
# book 145 summary links added
# book 146 summary links added
# book 147 summary links added
# book 148 summary links added
# book 149 summary links added
# book 150 summary links added
# book 151 summary links added
# book 152 summary links added
# book 153 summary links added
# book 154 summary links added
# book 155 summary links added
# book 156 summary links added
# book 157 summary links added
# book 158 summary links added
# book 159 summary links added
# book 160 summary links added
# book 161 summary links added
# book 162 summary links added
# book 163 summary links added
# book 164 summary links added
# book 165 summary links added
# book 166 summary links added
# book 167 summary links added
# book 168 summary links added
# book 169 summary links added
# book 170 summary links added
# book 171 summary links added
# book 172 summary links added
# book 173 summary links added
# book 174 summary links added
# book 175 summary links added
# book 176 summary links added
# book 177 summary links added
# book 178 summary links added
# book 179 summary links added
# book 180 summary links added
# book 181 summary links added
# book 182 summary links added
# book 183 summary links added
# book 184 summary links added
# book 185 summary links added
# book 186 summary links added
# book 187 summary links added
# book 188 summary links added
# book 189 summary links added
# book 190 summary links added
# book 191 summary links added
# book 192 summary links added
# book 193 summary links added
# book 194 summary links added
# book 195 summary links added
# book 196 summary links added
# book 197 summary links added
# book 198 summary links added
# book 199 summary links added
# book 200 summary links added
# book 201 summary links added
# book 202 summary links added
# book 203 summary links added
# book 204 summary links added
# book 205 summary links added
# book 206 summary links added
# book 207 summary links added
# book 208 summary links added
# book 209 summary links added
# book 210 summary links added
# book 211 summary links added
# book 212 summary links added
# book 213 summary links added
# book 214 summary links added
# book 215 summary links added
# book 216 summary links added
# book 217 summary links added
# book 218 summary links added
# book 219 summary links added
# book 220 summary links added
# book 221 summary links added
# book 222 summary links added
# book 223 summary links added
# book 224 summary links added
# book 225 summary links added
# book 226 summary links added
# book 227 summary links added
# book 228 summary links added
# book 229 summary links added
# book 230 summary links added
# book 231 summary links added
# book 232 summary links added
# book 233 summary links added
# book 234 summary links added
# book 235 summary links added
# book 236 summary links added
# book 237 summary links added
# book 238 summary links added
# book 239 summary links added
# book 240 summary links added
# book 241 summary links added
# book 242 summary links added
# book 243 summary links added
# book 244 summary links added
# book 245 summary links added
# book 246 summary links added
# book 247 summary links added
# book 248 summary links added
# book 249 summary links added
# book 250 summary links added
# book 251 summary links added
# book 252 summary links added
# book 253 summary links added
# book 254 summary links added
# book 255 summary links added
# book 256 summary links added
# book 257 summary links added
# book 258 summary links added
# book 259 summary links added
# book 260 summary links added
# book 261 summary links added
# book 262 summary links added
# book 263 summary links added
# book 264 summary links added
# book 265 summary links added
# book 266 summary links added
# book 267 summary links added
# book 268 summary links added
# book 269 summary links added
# book 270 summary links added
# book 271 summary links added
# book 272 summary links added
# book 273 summary links added
# book 274 summary links added
# book 275 summary links added
# book 276 summary links added
# book 277 summary links added
# book 278 summary links added
# book 279 summary links added
# book 280 summary links added
# book 281 summary links added
# book 282 summary links added
# book 283 summary links added
# book 284 summary links added
# book 285 summary links added
# book 286 summary links added
# book 287 summary links added
# book 288 summary links added
# book 289 summary links added
# book 290 summary links added
# book 291 summary links added
# book 292 summary links added
# book 293 summary links added
# book 294 summary links added
# book 295 summary links added
# book 296 summary links added
# book 297 summary links added
# book 298 summary links added
# book 299 summary links added
# book 300 summary links added
# book 301 summary links added
# book 302 summary links added
# book 303 summary links added
# book 304 summary links added
# book 305 summary links added
# book 306 summary links added
# book 307 summary links added
# book 308 summary links added
# book 309 summary links added
# book 310 summary links added
# book 311 summary links added
# book 312 summary links added
# book 313 summary links added
# book 314 summary links added
# book 315 summary links added
# book 316 summary links added
# book 317 summary links added
# book 318 summary links added
# book 319 summary links added
# book 320 summary links added
# book 321 summary links added
# book 322 summary links added
# book 323 summary links added
# book 324 summary links added
# book 325 summary links added
# book 326 summary links added
# book 327 summary links added
# book 328 summary links added
# book 329 summary links added
# book 330 summary links added
# book 331 summary links added
# book 332 summary links added
# book 333 summary links added
# book 334 summary links added
# book 335 summary links added
# book 336 summary links added
# book 337 summary links added
# book 338 summary links added
# book 339 summary links added
# book 340 summary links added
# book 341 summary links added
# book 342 summary links added
# book 343 summary links added
# book 344 summary links added
# book 345 summary links added
# book 346 summary links added
# book 347 summary links added
# book 348 summary links added
# book 349 summary links added
# book 350 summary links added
# book 351 summary links added
# book 352 summary links added
# book 353 summary links added
# book 354 summary links added
# book 355 summary links added
# book 356 summary links added
# book 357 summary links added
# book 358 summary links added
# book 359 summary links added
# book 360 summary links added
# book 361 summary links added
# book 362 summary links added
# book 363 summary links added
# book 364 summary links added
# book 365 summary links added
# book 366 summary links added
# book 367 summary links added
# book 368 summary links added
# book 369 summary links added
# book 370 summary links added
# book 371 summary links added
# book 372 summary links added
# book 373 summary links added
# book 374 summary links added
# book 375 summary links added
# book 376 summary links added
# book 377 summary links added
# book 378 summary links added
# book 379 summary links added
# book 380 summary links added
# book 381 summary links added

# %%
#Examine list created

book_summary_links[:2]
# Out:
# [{'title': 'The Ambassadors',
#   'summaries': ['https://novelguide.com/the-ambassadors/novel-summary']},
#  {'title': 'Ivanhoe',
#   'summaries': ['https://novelguide.com/ivanhoe/novel-summary']}]

# %%
#Number of entries in book summary links list - confirmed to be the same as book links
# (all books and corresponding summary links successfully scraped)

len(book_summary_links)
# Out:
# 382

# %% [markdown]
# ## Save book summary links to json file

# %%
with open('./data/working_data/book_summaries/book_summary_links.json', 'w') as fp:
    json.dump(book_summary_links, fp)

# %% [markdown]
# # Filter to usable summaries
# Texts for which both full text and chapter summaries are accessible
# <br>
# (see 01_02_crosscheck_summaries_text.ipynb for determination of usable texts)

# %%
#Read in dictionary of book summary links created in last step

with open('./data/working_data/book_summaries/book_summary_links.json') as json_file:
    book_summary_links = json.load(json_file)

# %%
#Read in dictionary of usable books (created in 01_02_crosscheck_summaries_texts.ipynb)

with open('./data/working_data/usable_books.json') as json_file:
    usable_books = json.load(json_file)

# %%
#Examine titles in usable books dictionary

usable_books.keys()
# Out:
# dict_keys(['Julius Caesar', 'David Copperfield', 'Crito', 'Madame Bovary', 'Of Human Bondage', 'Oliver Twist', 'Cyrano de Bergerac', 'A Tale of Two Cities', 'Cymbeline', "Uncle Tom's Cabin", 'Little Women', 'Walden', 'Macbeth', "Gulliver's Travels", 'The Awakening', 'Dubliners', 'Bleak House', 'A Christmas Carol', 'Beowulf', 'Merry Wives of Windsor', 'The Portrait of a Lady', 'Silas Marner', 'Wuthering Heights', 'The Call of the Wild', 'Middlemarch', 'The Canterbury Tales', 'Siddhartha', "A Connecticut Yankee in King Arthur's Court", 'Les Miserables', 'Divine Comedy', 'Ivanhoe', 'My Antonia', 'Hard Times', 'Phaedo', 'Candide', 'Henry VIII', 'Native Son', 'Meno', 'Notes from the Underground', 'The Count of Monte Cristo', 'Daisy Miller', 'The Comedy of Errors', 'King Lear', 'Adam Bede', 'Crime and Punishment', 'The Beast in the Jungle', 'As You Like It', 'The Adventures of Tom Sawyer', 'The Age of Innocence', 'The Scarlet Letter', 'The Secret Sharer', 'An Ideal Husband', 'Timon of Athens', 'The Republic', 'Pride and Prejudice', 'Turn of the Screw', 'The Jew of Malta', "The Winter's Tale", 'The Tempest', 'The Red Badge of Courage', 'Sister Carrie', 'Mansfield Park', 'Othello', 'The Iliad', 'Winesburg, Ohio', 'Twelfth Night', 'The Inferno', 'The Hound of the Baskervilles', 'The Adventures of Huckleberry Finn', 'Jude the Obscure', 'The Pearl', 'Persuasion', 'Richard III', 'The Jungle', 'Under the Greenwood Tree'])

# %%
#Create list of titles in book summaries scraped also included in the usable books titles 

usable_summaries = []
for summary in book_summary_links:
    if summary['title'] in list(usable_books.keys()):
        usable_summaries.append(summary)

# %%
#Number of usable titles in book summaries

len(usable_summaries)
# Out:
# 80

# %% [markdown]
# # Scrape summaries

# %% [markdown]
# ## Summary scraper

# %%
#Create empty lists to fill with titles and texts of chapter summaries, along with the corresponding book title for each
summary_titles = []
summary_texts = []
book_titles = []

#For each book in the list of usable summaries, iterate through the corresponding list of links to chapter summaries and 
# add the title and text of the summary to the corresponding list
b_num=1  #counter created to keep track of number of summaries scraped
for book in usable_summaries:
    s_num=1
    for s in book['summaries']:
        s_url = s
        s_response = requests.get(s_url)
        time.sleep(0.5)
        if s_response.status_code==200:
            s_html = s_response.text
            s_soup = BeautifulSoup(s_html, 'lxml')
            page_main_content = s_soup.find('div', {'id':'mainWrapper'}).find('div', {'id':'header'}).find('div', {'id':'page-wrapper'}).find('div', {'id':'main-content'})
            content_inner_inner = page_main_content.find('div', {'id':'content-inner'}).find('div', {'id':'content-inner-inner'})
            novel_guide_content= content_inner_inner.find('div', {'id':'content-content'}).find('div', {'id':'block-novelguide-content'})
            summary_text = novel_guide_content.find('div', {'class':'content'}).find('div', {'class':'clear-block'}).find('div', {'class':'content clear-block'}).find('div').text
            summary_title = content_inner_inner.find('h1', {'class':'title'}).text
            summary_titles.append(summary_title)
            summary_texts.append(summary_text)
            book_titles.append(book['title'])
            print(f'book {b_num} summary {s_num} added')
            s_num +=1
        else:
            print('Error with summary request')
    b_num +=1
# Out:
# book 1 summary 1 added
# book 2 summary 1 added
# book 2 summary 2 added
# book 2 summary 3 added
# book 3 summary 1 added
# book 3 summary 2 added
# book 3 summary 3 added
# book 3 summary 4 added
# book 3 summary 5 added
# book 3 summary 6 added
# book 3 summary 7 added
# book 3 summary 8 added
# book 3 summary 9 added
# book 3 summary 10 added
# book 3 summary 11 added
# book 3 summary 12 added
# book 3 summary 13 added
# book 3 summary 14 added
# book 4 summary 1 added
# book 4 summary 2 added
# book 4 summary 3 added
# book 4 summary 4 added
# book 4 summary 5 added
# book 4 summary 6 added
# book 4 summary 7 added
# book 4 summary 8 added
# book 4 summary 9 added
# book 4 summary 10 added
# book 4 summary 11 added
# book 4 summary 12 added
# book 4 summary 13 added
# book 4 summary 14 added
# book 4 summary 15 added
# book 5 summary 1 added
# book 5 summary 2 added
# book 5 summary 3 added
# book 5 summary 4 added
# book 5 summary 5 added
# book 5 summary 6 added
# book 5 summary 7 added
# book 5 summary 8 added
# book 5 summary 9 added
# book 5 summary 10 added
# book 5 summary 11 added
# book 5 summary 12 added
# book 6 summary 1 added
# book 6 summary 2 added
# book 6 summary 3 added
# book 6 summary 4 added
# book 6 summary 5 added
# book 6 summary 6 added
# book 6 summary 7 added
# book 6 summary 8 added
# book 6 summary 9 added
# book 6 summary 10 added
# book 6 summary 11 added
# book 6 summary 12 added
# book 7 summary 1 added
# book 7 summary 2 added
# book 7 summary 3 added
# book 7 summary 4 added
# book 7 summary 5 added
# book 7 summary 6 added
# book 7 summary 7 added
# book 7 summary 8 added
# book 8 summary 1 added
# book 8 summary 2 added
# book 8 summary 3 added
# book 8 summary 4 added
# book 8 summary 5 added
# book 8 summary 6 added
# book 8 summary 7 added
# book 8 summary 8 added
# book 8 summary 9 added
# book 8 summary 10 added
# book 8 summary 11 added
# book 8 summary 12 added
# book 8 summary 13 added
# book 8 summary 14 added
# book 8 summary 15 added
# book 8 summary 16 added
# book 8 summary 17 added
# book 9 summary 1 added
# book 9 summary 2 added
# book 9 summary 3 added
# book 9 summary 4 added
# book 9 summary 5 added
# book 9 summary 6 added
# book 9 summary 7 added
# book 9 summary 8 added
# book 9 summary 9 added
# book 9 summary 10 added
# book 9 summary 11 added
# book 9 summary 12 added
# book 10 summary 1 added
# book 11 summary 1 added
# book 12 summary 1 added
# book 12 summary 2 added
# book 12 summary 3 added
# book 12 summary 4 added
# book 12 summary 5 added
# book 12 summary 6 added
# book 12 summary 7 added
# book 12 summary 8 added
# book 12 summary 9 added
# book 12 summary 10 added
# book 12 summary 11 added
# book 12 summary 12 added
# book 12 summary 13 added
# book 12 summary 14 added
# book 12 summary 15 added
# book 13 summary 1 added
# book 13 summary 2 added
# book 13 summary 3 added
# book 13 summary 4 added
# book 13 summary 5 added
# book 13 summary 6 added
# book 13 summary 7 added
# book 13 summary 8 added
# book 13 summary 9 added
# book 13 summary 10 added
# book 13 summary 11 added
# book 13 summary 12 added
# book 13 summary 13 added
# book 14 summary 1 added
# book 15 summary 1 added
# book 15 summary 2 added
# book 15 summary 3 added
# book 15 summary 4 added
# book 15 summary 5 added
# book 15 summary 6 added
# book 15 summary 7 added
# book 15 summary 8 added
# book 15 summary 9 added
# book 15 summary 10 added
# book 15 summary 11 added
# book 16 summary 1 added
# book 16 summary 2 added
# book 16 summary 3 added
# book 16 summary 4 added
# book 16 summary 5 added
# book 16 summary 6 added
# book 16 summary 7 added
# book 16 summary 8 added
# book 16 summary 9 added
# book 16 summary 10 added
# book 16 summary 11 added
# book 16 summary 12 added
# book 17 summary 1 added
# book 17 summary 2 added
# book 17 summary 3 added
# book 17 summary 4 added
# book 17 summary 5 added
# book 17 summary 6 added
# book 17 summary 7 added
# book 17 summary 8 added
# book 17 summary 9 added
# book 17 summary 10 added
# book 17 summary 11 added
# book 18 summary 1 added
# book 18 summary 2 added
# book 18 summary 3 added
# book 18 summary 4 added
# book 18 summary 5 added
# book 18 summary 6 added
# book 18 summary 7 added
# book 18 summary 8 added
# book 18 summary 9 added
# book 18 summary 10 added
# book 18 summary 11 added
# book 18 summary 12 added
# book 18 summary 13 added
# book 18 summary 14 added
# book 19 summary 1 added
# book 20 summary 1 added
# book 21 summary 1 added
# book 22 summary 1 added
# book 22 summary 2 added
# book 22 summary 3 added
# book 22 summary 4 added
# book 22 summary 5 added
# book 22 summary 6 added
# book 22 summary 7 added
# book 22 summary 8 added
# book 22 summary 9 added
# book 22 summary 10 added
# book 22 summary 11 added
# book 22 summary 12 added
# book 22 summary 13 added
# book 22 summary 14 added
# book 22 summary 15 added
# book 22 summary 16 added
# book 22 summary 17 added
# book 23 summary 1 added
# book 23 summary 2 added
# book 23 summary 3 added
# book 23 summary 4 added
# book 23 summary 5 added
# book 23 summary 6 added
# book 23 summary 7 added
# book 23 summary 8 added
# book 23 summary 9 added
# book 23 summary 10 added
# book 23 summary 11 added
# book 23 summary 12 added
# book 23 summary 13 added
# book 23 summary 14 added
# book 23 summary 15 added
# book 23 summary 16 added
# book 24 summary 1 added
# book 24 summary 2 added
# book 24 summary 3 added
# book 24 summary 4 added
# book 24 summary 5 added
# book 24 summary 6 added
# book 24 summary 7 added
# book 24 summary 8 added
# book 24 summary 9 added
# book 24 summary 10 added
# book 24 summary 11 added
# book 24 summary 12 added
# book 24 summary 13 added
# book 24 summary 14 added
# book 25 summary 1 added
# book 26 summary 1 added
# book 26 summary 2 added
# book 26 summary 3 added
# book 26 summary 4 added
# book 26 summary 5 added
# book 26 summary 6 added
# book 26 summary 7 added
# book 26 summary 8 added
# book 26 summary 9 added
# book 26 summary 10 added
# book 26 summary 11 added
# book 26 summary 12 added
# book 26 summary 13 added
# book 26 summary 14 added
# book 26 summary 15 added
# book 26 summary 16 added
# book 26 summary 17 added
# book 26 summary 18 added
# book 26 summary 19 added
# book 26 summary 20 added
# book 26 summary 21 added
# book 26 summary 22 added
# book 26 summary 23 added
# book 26 summary 24 added
# book 26 summary 25 added
# book 26 summary 26 added
# book 26 summary 27 added
# book 26 summary 28 added
# book 27 summary 1 added
# book 28 summary 1 added
# book 29 summary 1 added
# book 29 summary 2 added
# book 29 summary 3 added
# book 29 summary 4 added
# book 29 summary 5 added
# book 29 summary 6 added
# book 29 summary 7 added
# book 29 summary 8 added
# book 29 summary 9 added
# book 29 summary 10 added
# book 29 summary 11 added
# book 29 summary 12 added
# book 29 summary 13 added
# book 29 summary 14 added
# book 29 summary 15 added
# book 30 summary 1 added
# book 30 summary 2 added
# book 30 summary 3 added
# book 30 summary 4 added
# book 30 summary 5 added
# book 30 summary 6 added
# book 30 summary 7 added
# book 30 summary 8 added
# book 30 summary 9 added
# book 30 summary 10 added
# book 30 summary 11 added
# book 30 summary 12 added
# book 30 summary 13 added
# book 30 summary 14 added
# book 30 summary 15 added
# book 30 summary 16 added
# book 30 summary 17 added
# book 30 summary 18 added
# book 30 summary 19 added
# book 30 summary 20 added
# book 30 summary 21 added
# book 30 summary 22 added
# book 30 summary 23 added
# book 30 summary 24 added
# book 30 summary 25 added
# book 30 summary 26 added
# book 30 summary 27 added
# book 30 summary 28 added
# book 31 summary 1 added
# book 32 summary 1 added
# book 32 summary 2 added
# book 32 summary 3 added
# book 32 summary 4 added
# book 32 summary 5 added
# book 32 summary 6 added
# book 32 summary 7 added
# book 32 summary 8 added
# book 32 summary 9 added
# book 32 summary 10 added
# book 32 summary 11 added
# book 32 summary 12 added
# book 32 summary 13 added
# book 33 summary 1 added
# book 33 summary 2 added
# book 33 summary 3 added
# book 33 summary 4 added
# book 33 summary 5 added
# book 33 summary 6 added
# book 33 summary 7 added
# book 33 summary 8 added
# book 33 summary 9 added
# book 33 summary 10 added
# book 33 summary 11 added
# book 33 summary 12 added
# book 33 summary 13 added
# book 33 summary 14 added
# book 33 summary 15 added
# book 34 summary 1 added
# book 35 summary 1 added
# book 36 summary 1 added
# book 36 summary 2 added
# book 36 summary 3 added
# book 36 summary 4 added
# book 36 summary 5 added
# book 36 summary 6 added
# book 36 summary 7 added
# book 36 summary 8 added
# book 36 summary 9 added
# book 36 summary 10 added
# book 36 summary 11 added
# book 36 summary 12 added
# book 36 summary 13 added
# book 36 summary 14 added
# book 36 summary 15 added
# book 36 summary 16 added
# book 36 summary 17 added
# book 36 summary 18 added
# book 36 summary 19 added
# book 36 summary 20 added
# book 36 summary 21 added
# book 36 summary 22 added
# book 36 summary 23 added
# book 36 summary 24 added
# book 36 summary 25 added
# book 36 summary 26 added
# book 36 summary 27 added
# book 36 summary 28 added
# book 36 summary 29 added
# book 36 summary 30 added
# book 36 summary 31 added
# book 36 summary 32 added
# book 36 summary 33 added
# book 36 summary 34 added
# book 36 summary 35 added
# book 36 summary 36 added
# book 36 summary 37 added
# book 36 summary 38 added
# book 36 summary 39 added
# book 36 summary 40 added
# book 36 summary 41 added
# book 36 summary 42 added
# book 36 summary 43 added
# book 36 summary 44 added
# book 36 summary 45 added
# book 36 summary 46 added
# book 36 summary 47 added
# book 36 summary 48 added
# book 36 summary 49 added
# book 37 summary 1 added
# book 37 summary 2 added
# book 37 summary 3 added
# book 37 summary 4 added
# book 37 summary 5 added
# book 37 summary 6 added
# book 37 summary 7 added
# book 37 summary 8 added
# book 37 summary 9 added
# book 37 summary 10 added
# book 37 summary 11 added
# book 37 summary 12 added
# book 37 summary 13 added
# book 37 summary 14 added
# book 37 summary 15 added
# book 37 summary 16 added
# book 37 summary 17 added
# book 37 summary 18 added
# book 37 summary 19 added
# book 37 summary 20 added
# book 38 summary 1 added
# book 38 summary 2 added
# book 38 summary 3 added
# book 38 summary 4 added
# book 38 summary 5 added
# book 38 summary 6 added
# book 38 summary 7 added
# book 38 summary 8 added
# book 38 summary 9 added
# book 38 summary 10 added
# book 38 summary 11 added
# book 38 summary 12 added
# book 39 summary 1 added
# book 39 summary 2 added
# book 39 summary 3 added
# book 39 summary 4 added
# book 39 summary 5 added
# book 39 summary 6 added
# book 39 summary 7 added
# book 39 summary 8 added
# book 39 summary 9 added
# book 39 summary 10 added
# book 39 summary 11 added
# book 40 summary 1 added
# book 40 summary 2 added
# book 40 summary 3 added
# book 40 summary 4 added
# book 40 summary 5 added
# book 40 summary 6 added
# book 40 summary 7 added
# book 40 summary 8 added
# book 40 summary 9 added
# book 40 summary 10 added
# book 40 summary 11 added
# book 40 summary 12 added
# book 40 summary 13 added
# book 40 summary 14 added
# book 40 summary 15 added
# book 41 summary 1 added
# book 41 summary 2 added
# book 41 summary 3 added
# book 41 summary 4 added
# book 41 summary 5 added
# book 41 summary 6 added
# book 41 summary 7 added
# book 41 summary 8 added
# book 41 summary 9 added
# book 41 summary 10 added
# book 41 summary 11 added
# book 41 summary 12 added
# book 41 summary 13 added
# book 41 summary 14 added
# book 41 summary 15 added
# book 41 summary 16 added
# book 41 summary 17 added
# book 41 summary 18 added
# book 41 summary 19 added
# book 41 summary 20 added
# book 41 summary 21 added
# book 42 summary 1 added
# book 42 summary 2 added
# book 42 summary 3 added
# book 42 summary 4 added
# book 42 summary 5 added
# book 42 summary 6 added
# book 42 summary 7 added
# book 42 summary 8 added
# book 42 summary 9 added
# book 42 summary 10 added
# book 42 summary 11 added
# book 42 summary 12 added
# book 42 summary 13 added
# book 42 summary 14 added
# book 42 summary 15 added
# book 43 summary 1 added
# book 43 summary 2 added
# book 43 summary 3 added
# book 43 summary 4 added
# book 43 summary 5 added
# book 43 summary 6 added
# book 43 summary 7 added
# book 43 summary 8 added
# book 43 summary 9 added
# book 43 summary 10 added
# book 43 summary 11 added
# book 43 summary 12 added
# book 43 summary 13 added
# book 43 summary 14 added
# book 43 summary 15 added
# book 43 summary 16 added
# book 43 summary 17 added
# book 43 summary 18 added
# book 44 summary 1 added
# book 44 summary 2 added
# book 44 summary 3 added
# book 44 summary 4 added
# book 44 summary 5 added
# book 44 summary 6 added
# book 44 summary 7 added
# book 44 summary 8 added
# book 44 summary 9 added
# book 44 summary 10 added
# book 44 summary 11 added
# book 44 summary 12 added
# book 45 summary 1 added
# book 46 summary 1 added
# book 46 summary 2 added
# book 46 summary 3 added
# book 46 summary 4 added
# book 46 summary 5 added
# book 46 summary 6 added
# book 46 summary 7 added
# book 46 summary 8 added
# book 46 summary 9 added
# book 46 summary 10 added
# book 46 summary 11 added
# book 46 summary 12 added
# book 47 summary 1 added
# book 48 summary 1 added
# book 48 summary 2 added
# book 48 summary 3 added
# book 48 summary 4 added
# book 48 summary 5 added
# book 48 summary 6 added
# book 48 summary 7 added
# book 48 summary 8 added
# book 48 summary 9 added
# book 48 summary 10 added
# book 48 summary 11 added
# book 48 summary 12 added
# book 48 summary 13 added
# book 48 summary 14 added
# book 48 summary 15 added
# book 49 summary 1 added
# book 50 summary 1 added
# book 50 summary 2 added
# book 50 summary 3 added
# book 50 summary 4 added
# book 50 summary 5 added
# book 50 summary 6 added
# book 50 summary 7 added
# book 50 summary 8 added
# book 51 summary 1 added
# book 52 summary 1 added
# book 52 summary 2 added
# book 52 summary 3 added
# book 52 summary 4 added
# book 52 summary 5 added
# book 52 summary 6 added
# book 52 summary 7 added
# book 52 summary 8 added
# book 52 summary 9 added
# book 52 summary 10 added
# book 53 summary 1 added
# book 53 summary 2 added
# book 53 summary 3 added
# book 54 summary 1 added
# book 54 summary 2 added
# book 54 summary 3 added
# book 54 summary 4 added
# book 54 summary 5 added
# book 54 summary 6 added
# book 54 summary 7 added
# book 54 summary 8 added
# book 54 summary 9 added
# book 54 summary 10 added
# book 54 summary 11 added
# book 54 summary 12 added
# book 54 summary 13 added
# book 55 summary 1 added
# book 55 summary 2 added
# book 55 summary 3 added
# book 55 summary 4 added
# book 55 summary 5 added
# book 55 summary 6 added
# book 55 summary 7 added
# book 55 summary 8 added
# book 55 summary 9 added
# book 55 summary 10 added
# book 55 summary 11 added
# book 55 summary 12 added
# book 56 summary 1 added
# book 56 summary 2 added
# book 56 summary 3 added
# book 57 summary 1 added
# book 57 summary 2 added
# book 57 summary 3 added
# book 57 summary 4 added
# book 57 summary 5 added
# book 57 summary 6 added
# book 58 summary 1 added
# book 58 summary 2 added
# book 58 summary 3 added
# book 58 summary 4 added
# book 58 summary 5 added
# book 58 summary 6 added
# book 58 summary 7 added
# book 58 summary 8 added
# book 58 summary 9 added
# book 58 summary 10 added
# book 58 summary 11 added
# book 58 summary 12 added
# book 58 summary 13 added
# book 58 summary 14 added
# book 58 summary 15 added
# book 58 summary 16 added
# book 58 summary 17 added
# book 58 summary 18 added
# book 59 summary 1 added
# book 60 summary 1 added
# book 60 summary 2 added
# book 60 summary 3 added
# book 60 summary 4 added
# book 60 summary 5 added
# book 60 summary 6 added
# book 60 summary 7 added
# book 60 summary 8 added
# book 60 summary 9 added
# book 60 summary 10 added
# book 60 summary 11 added
# book 60 summary 12 added
# book 60 summary 13 added
# book 60 summary 14 added
# book 60 summary 15 added
# book 60 summary 16 added
# book 60 summary 17 added
# book 60 summary 18 added
# book 60 summary 19 added
# book 60 summary 20 added
# book 60 summary 21 added
# book 60 summary 22 added
# book 60 summary 23 added
# book 60 summary 24 added
# book 60 summary 25 added
# book 61 summary 1 added
# book 61 summary 2 added
# book 61 summary 3 added
# book 61 summary 4 added
# book 61 summary 5 added
# book 61 summary 6 added
# book 61 summary 7 added
# book 61 summary 8 added
# book 61 summary 9 added
# book 61 summary 10 added
# book 61 summary 11 added
# book 61 summary 12 added
# book 61 summary 13 added
# book 61 summary 14 added
# book 61 summary 15 added
# book 61 summary 16 added
# book 61 summary 17 added
# book 61 summary 18 added
# book 61 summary 19 added
# book 61 summary 20 added
# book 61 summary 21 added
# book 61 summary 22 added
# book 61 summary 23 added
# book 61 summary 24 added
# book 61 summary 25 added
# book 62 summary 1 added
# book 62 summary 2 added
# book 62 summary 3 added
# book 62 summary 4 added
# book 62 summary 5 added
# book 62 summary 6 added
# book 63 summary 1 added
# book 64 summary 1 added
# book 64 summary 2 added
# book 64 summary 3 added
# book 64 summary 4 added
# book 65 summary 1 added
# book 65 summary 2 added
# book 65 summary 3 added
# book 65 summary 4 added
# book 65 summary 5 added
# book 65 summary 6 added
# book 65 summary 7 added
# book 65 summary 8 added
# book 65 summary 9 added
# book 65 summary 10 added
# book 65 summary 11 added
# book 65 summary 12 added
# book 65 summary 13 added
# book 65 summary 14 added
# book 65 summary 15 added
# book 65 summary 16 added
# book 65 summary 17 added
# book 65 summary 18 added
# book 66 summary 1 added
# book 66 summary 2 added
# book 66 summary 3 added
# book 66 summary 4 added
# book 66 summary 5 added
# book 66 summary 6 added
# book 66 summary 7 added
# book 66 summary 8 added
# book 66 summary 9 added
# book 66 summary 10 added
# book 66 summary 11 added
# book 66 summary 12 added
# book 66 summary 13 added
# book 66 summary 14 added
# book 66 summary 15 added
# book 66 summary 16 added
# book 66 summary 17 added
# book 66 summary 18 added
# book 66 summary 19 added
# book 66 summary 20 added
# book 66 summary 21 added
# book 66 summary 22 added
# book 66 summary 23 added
# book 66 summary 24 added
# book 66 summary 25 added
# book 66 summary 26 added
# book 66 summary 27 added
# book 66 summary 28 added
# book 66 summary 29 added
# book 66 summary 30 added
# book 67 summary 1 added
# book 67 summary 2 added
# book 67 summary 3 added
# book 67 summary 4 added
# book 67 summary 5 added
# book 67 summary 6 added
# book 67 summary 7 added
# book 67 summary 8 added
# book 67 summary 9 added
# book 67 summary 10 added
# book 67 summary 11 added
# book 67 summary 12 added
# book 67 summary 13 added
# book 67 summary 14 added
# book 67 summary 15 added
# book 67 summary 16 added
# book 67 summary 17 added
# book 67 summary 18 added
# book 68 summary 1 added
# book 68 summary 2 added
# book 68 summary 3 added
# book 68 summary 4 added
# book 68 summary 5 added
# book 68 summary 6 added
# book 69 summary 1 added
# book 69 summary 2 added
# book 69 summary 3 added
# book 69 summary 4 added
# book 69 summary 5 added
# book 69 summary 6 added
# book 69 summary 7 added
# book 69 summary 8 added
# book 69 summary 9 added
# book 69 summary 10 added
# book 69 summary 11 added
# book 70 summary 1 added
# book 70 summary 2 added
# book 70 summary 3 added
# book 71 summary 1 added
# book 71 summary 2 added
# book 71 summary 3 added
# book 71 summary 4 added
# book 71 summary 5 added
# book 71 summary 6 added
# book 71 summary 7 added
# book 71 summary 8 added
# book 71 summary 9 added
# book 71 summary 10 added
# book 71 summary 11 added
# book 71 summary 12 added
# book 71 summary 13 added
# book 71 summary 14 added
# book 72 summary 1 added
# book 72 summary 2 added
# book 72 summary 3 added
# book 72 summary 4 added
# book 72 summary 5 added
# book 72 summary 6 added
# book 73 summary 1 added
# book 73 summary 2 added
# book 73 summary 3 added
# book 73 summary 4 added
# book 73 summary 5 added
# book 73 summary 6 added
# book 73 summary 7 added
# book 73 summary 8 added
# book 73 summary 9 added
# book 73 summary 10 added
# book 73 summary 11 added
# book 73 summary 12 added
# book 73 summary 13 added
# book 73 summary 14 added
# book 74 summary 1 added
# book 75 summary 1 added
# book 75 summary 2 added
# book 75 summary 3 added
# book 75 summary 4 added
# book 75 summary 5 added
# book 75 summary 6 added
# book 75 summary 7 added
# book 75 summary 8 added
# book 75 summary 9 added
# book 75 summary 10 added
# book 75 summary 11 added
# book 75 summary 12 added
# book 75 summary 13 added
# book 75 summary 14 added
# book 75 summary 15 added
# book 75 summary 16 added
# book 76 summary 1 added
# book 76 summary 2 added
# book 76 summary 3 added
# book 76 summary 4 added
# book 76 summary 5 added
# book 76 summary 6 added
# book 76 summary 7 added
# book 76 summary 8 added
# book 76 summary 9 added
# book 76 summary 10 added
# book 76 summary 11 added
# book 76 summary 12 added
# book 76 summary 13 added
# book 76 summary 14 added
# book 77 summary 1 added
# book 77 summary 2 added
# book 77 summary 3 added
# book 78 summary 1 added
# book 78 summary 2 added
# book 78 summary 3 added
# book 78 summary 4 added
# book 78 summary 5 added
# book 78 summary 6 added
# book 78 summary 7 added
# book 78 summary 8 added
# book 78 summary 9 added
# book 78 summary 10 added
# book 78 summary 11 added
# book 78 summary 12 added
# book 78 summary 13 added
# book 78 summary 14 added
# book 78 summary 15 added
# book 78 summary 16 added
# book 78 summary 17 added
# book 78 summary 18 added
# book 78 summary 19 added
# book 78 summary 20 added
# book 78 summary 21 added
# book 78 summary 22 added
# book 78 summary 23 added
# book 78 summary 24 added
# book 78 summary 25 added
# book 79 summary 1 added
# book 79 summary 2 added
# book 79 summary 3 added
# book 79 summary 4 added
# book 79 summary 5 added
# book 79 summary 6 added
# book 79 summary 7 added
# book 79 summary 8 added
# book 79 summary 9 added
# book 79 summary 10 added
# book 79 summary 11 added
# book 79 summary 12 added
# book 80 summary 1 added
# book 80 summary 2 added
# book 80 summary 3 added
# book 80 summary 4 added

# %%
#Total number of book chapter summaries scraped

len(summary_texts)
# Out:
# 862

# %% [markdown]
# ## Create dataframe of summaries scraped

# %%
df_summaries = pd.DataFrame(np.ones(862))

# %%
df_summaries['title'] = summary_titles

# %%
df_summaries
# Out:
#        0                                              title
# 0    1.0                                   Ivanhoe: Summary
# 1    1.0                    Crito: Novel Summary: Chapter 1
# 2    1.0        NovelGuide: Crito: Novel Summary: Chapter 2
# 3    1.0        NovelGuide: Crito: Novel Summary: Chapter 3
# 4    1.0                  Henry VIII: Summary: The Prologue
# ..   ...                                                ...
# 857  1.0           The Iliad: Novel Summary: Chapters 23-24
# 858  1.0  The Hound of the Baskervilles: Novel Summary: ...
# 859  1.0  The Hound of the Baskervilles: Novel Summary: ...
# 860  1.0  The Hound of the Baskervilles: Novel Summary: ...
# 861  1.0  The Hound of the Baskervilles: Novel Summary: ...
#
# [862 rows x 2 columns]

# %%
df_summaries['text'] = summary_texts

# %%
df_summaries['book_title'] = book_titles

# %%
df_summaries.drop(columns=0)
# Out:
#                                                  title  \
# 0                                     Ivanhoe: Summary
# 1                      Crito: Novel Summary: Chapter 1
# 2          NovelGuide: Crito: Novel Summary: Chapter 2
# 3          NovelGuide: Crito: Novel Summary: Chapter 3
# 4                    Henry VIII: Summary: The Prologue
# ..                                                 ...
# 857           The Iliad: Novel Summary: Chapters 23-24
# 858  The Hound of the Baskervilles: Novel Summary: ...
# 859  The Hound of the Baskervilles: Novel Summary: ...
# 860  The Hound of the Baskervilles: Novel Summary: ...
# 861  The Hound of the Baskervilles: Novel Summary: ...
#
#                                                   text  \
# 0    Chapter I\n\tThe story is set in England in th...
# 1    In 399 B.C., Athens sought someone to blame fo...
# 2    Crito enters the cell, depressed himself at th...
# 3    In this part of the dialogue, Socrates gets to...
# 4    \n\tThe Prologue enters and explains that he i...
# ..                                                 ...
# 857  Chapter 23: The Greeks finish their mourning f...
# 858   \nNote: All page numbers in this summary and ...
# 859   \nSummary: Mortimer reads to Holmes and Watso...
# 860   \nSummary: Holmes urges Watson to report any ...
# 861   \nSummary: Watson questions Laura Lyons, who ...
#
#                         book_title
# 0                          Ivanhoe
# 1                            Crito
# 2                            Crito
# 3                            Crito
# 4                       Henry VIII
# ..                             ...
# 857                      The Iliad
# 858  The Hound of the Baskervilles
# 859  The Hound of the Baskervilles
# 860  The Hound of the Baskervilles
# 861  The Hound of the Baskervilles
#
# [862 rows x 3 columns]

# %%
df_summaries.drop(columns=0, inplace=True)

# %%
df_summaries.head()
# Out:
#                                          title  \
# 0                             Ivanhoe: Summary
# 1              Crito: Novel Summary: Chapter 1
# 2  NovelGuide: Crito: Novel Summary: Chapter 2
# 3  NovelGuide: Crito: Novel Summary: Chapter 3
# 4            Henry VIII: Summary: The Prologue
#
#                                                 text  book_title
# 0  Chapter I\n\tThe story is set in England in th...     Ivanhoe
# 1  In 399 B.C., Athens sought someone to blame fo...       Crito
# 2  Crito enters the cell, depressed himself at th...       Crito
# 3  In this part of the dialogue, Socrates gets to...       Crito
# 4  \n\tThe Prologue enters and explains that he i...  Henry VIII

# %%
df_summaries.shape
# Out:
# (862, 3)

# %% [markdown]
# ## Export summaries dataframe to csv

# %%
df_summaries.to_csv('./data/working_data/book_summaries/summaries.csv')
