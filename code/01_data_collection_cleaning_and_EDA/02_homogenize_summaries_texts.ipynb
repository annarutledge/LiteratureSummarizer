# %% [markdown]
# # Imports

# %%
import pandas as pd
import json

# %% [markdown]
# # Read in data

# %%
#Read in summaries data

df_summaries = pd.read_csv('./data/working_data/book_summaries/summaries.csv')

# %%
df_summaries.head(2)
# Out:
#    Unnamed: 0                            title  \
# 0           0                 Ivanhoe: Summary
# 1           1  Crito: Novel Summary: Chapter 1
#
#                                                 text book_title
# 0  Chapter I\n\tThe story is set in England in th...    Ivanhoe
# 1  In 399 B.C., Athens sought someone to blame fo...      Crito

# %%
df_summaries.drop(columns='Unnamed: 0', inplace=True)

# %%
df_summaries.head(2)
# Out:
#                              title  \
# 0                 Ivanhoe: Summary
# 1  Crito: Novel Summary: Chapter 1
#
#                                                 text book_title
# 0  Chapter I\n\tThe story is set in England in th...    Ivanhoe
# 1  In 399 B.C., Athens sought someone to blame fo...      Crito

# %%
#Read in full texts data

df_texts = pd.read_csv('./data/working_data/book_texts/full_texts.csv')

# %%
df_texts.head(2)
# Out:
#    Unnamed: 0                                            title  \
# 0           0                  The Scarlet Letter by Hawthorne
# 1           1  The Hound of the Baskervilles by A. Conan Doyle
#
#                                                 text
# 0  The Scarlet LetterbyHawthorne\n\n\n\n\n\r\nTHE...
# 1  The Hound of the BaskervillesbyA. Conan Doyle\...

# %%
df_texts.drop(columns='Unnamed: 0', inplace=True)

# %%
df_texts.head(2)
# Out:
#                                              title  \
# 0                  The Scarlet Letter by Hawthorne
# 1  The Hound of the Baskervilles by A. Conan Doyle
#
#                                                 text
# 0  The Scarlet LetterbyHawthorne\n\n\n\n\n\r\nTHE...
# 1  The Hound of the BaskervillesbyA. Conan Doyle\...

# %% [markdown]
# # Match up book titles in two dataframes

# %%
#Number of columns in df_texts

len(df_texts)
# Out:
# 45

# %%
#Number of columns in df_summaries

len(df_summaries['book_title'].unique())
# Out:
# 51

# %%
#Open dictionary of full text book titles to summary book titles

with open('./data/working_data/fulltext_to_summary_dict.json') as json_file:
    fulltext_to_summary = json.load(json_file)

# %%
fulltext_to_summary
# Out:
# {'The Scarlet Letter by Hawthorne': 'The Scarlet Letter',
#  'The Hound of the Baskervilles by A. Conan Doyle': 'The Hound of the Baskervilles',
#  'The Life of Henry VIII by William Shakespeare [Dunlap edition]': 'Henry VIII',
#  'Of Human Bondage by W. Somerset Maugham': 'Of Human Bondage',
#  'The Complete Works of William Shakespeare Cymbeline': 'Cymbeline',
#  'Ivanhoe by Walter Scott': 'Ivanhoe',
#  'My Antonia by Willa Cather': 'My Antonia',
#  'The Call of the Wild, by Jack London': 'The Call of the Wild',
#  'The Adventures of Tom Sawyer, Complete by Mark Twain (Samuel Clemens)': 'The Adventures of Tom Sawyer',
#  'Candide by Voltaire': 'Candide',
#  'The Age of Innocence by Edith Wharton': 'The Age of Innocence',
#  'The Canterbury Tales and Other Poems by Geoffrey Chaucer': 'The Canterbury Tales',
#  'Daisy Miller, by Henry James': 'Daisy Miller',
#  'Pride and Prejudice by Jane Austen': 'Pride and Prejudice',
#  'Winesburg, Ohio by Sherwood Anderson': 'Winesburg, Ohio',
#  'The Adventures of Huckleberry Finn by Mark Twain (Samuel Clemens)': 'The Adventures of Huckleberry Finn',
#  'The Jungle, by Upton Sinclair': 'The Jungle',
#  'Oliver Twist by Charles Dickens': 'Oliver Twist',
#  'The Complete Works of William Shakespeare As You Like It': 'As You Like It',
#  'Madame Bovary by Gustave Flaubert': 'Madame Bovary',
#  'Middlemarch by George Eliot': 'Middlemarch',
#  'A Christmas Carol by Charles Dickens': 'A Christmas Carol',
#  'A Tale of Two Cities, by Charles Dickens [A story of the French Revolution]': 'A Tale of Two Cities',
#  'The Jew of Malta by Christopher Marlowe': 'The Jew of Malta',
#  'Under the Greenwood Tree by Thomas Hardy': 'Under the Greenwood Tree',
#  'Notes from the Underground, by Feodor Dostoevsky': 'Notes from the Underground',
#  'Adam Bede by George Eliot  [pseudonym of Mary Anne Evans]': 'Adam Bede',
#  'The Inferno by Henri Barbusse': 'The Inferno',
#  'The Pearl by Sophie Jewett': 'The Pearl',
#  'The Native Son by Inez Haynes Irwin': 'Native Son',
#  "The Complete Works of William Shakespeare The Winter's Tale": "The Winter's Tale",
#  'The Complete Works of William Shakespeare The Tragedy of Julius Caesar': 'Julius Caesar',
#  'Crito by Plato': 'Crito',
#  'An Ideal Husband by Oscar Wilde': 'An Ideal Husband',
#  'Crime and Punishment by Fyodor Dostoevsky': 'Crime and Punishment',
#  "Dante's Inferno [Divine Comedy]": 'Divine Comedy',
#  'The Complete Works of William Shakespeare The Merry Wives of Windsor': 'Merry Wives of Windsor',
#  'The Awakening and Selected Short Stories by Kate Chopin': 'The Awakening',
#  'The Complete Works of William Shakespeare Twelfth Night; or What You Will': 'Twelfth Night',
#  'The Secret Sharer, by Joseph Conrad': 'The Secret Sharer',
#  'The Count of Monte Cristo by Alexandre Dumas [Pere]': 'The Count of Monte Cristo',
#  'The Complete Works of William Shakespeare The Life of Timon of Athens': 'Timon of Athens',
#  'The Red Badge of Courage by Stephen Crane': 'The Red Badge of Courage',
#  'The Complete Works of William Shakespeare The Tragedy of King Lear': 'King Lear',
#  'Wuthering Heights by Emily Bronte': 'Wuthering Heights',
#  'Hard Times by Charles Dickens*': 'Hard Times',
#  'Little Women by Louisa May Alcott': 'Little Women',
#  'Dubliners by James Joyce': 'Dubliners',
#  'Persuasion, by Jane Austen': 'Persuasion',
#  'Bleak House by Charles Dickens': 'Bleak House',
#  'Mansfield Park, by Jane Austen (1775-1817)': 'Mansfield Park',
#  'David Copperfield by Charles Dickens': 'David Copperfield',
#  'Beowulf by James A. Harrison and Robert Sharp, eds.': 'Beowulf',
#  'The Beast in the Jungle by Henry James': 'The Beast in the Jungle',
#  'The Complete Works of William Shakespeare The Tempest': 'The Tempest',
#  'The Complete Works of William Shakespeare The Tragedy of Othello, Moor of Venice': 'Othello',
#  'The Complete Works of William Shakespeare The Tragedy of Macbeth': 'Macbeth',
#  'The Republic by Plato, translated by B. Jowett': 'The Republic',
#  'Silas Marner by George Eliot': 'Silas Marner',
#  'Cyrano de Bergerac by Edmond Rostand': 'Cyrano de Bergerac',
#  'The Portrait of a Lady  [Volume 2] by Henry James': 'The Portrait of a Lady',
#  'The Portrait of a Lady  [Volume 1] by Henry James': 'The Portrait of a Lady',
#  "A Connecticut Yankee in King Arthur's Court, Complete by Mark Twain (Samuel Clemens)": "A Connecticut Yankee in King Arthur's Court",
#  'Sister Carrie, by Theodore Dreiser': 'Sister Carrie',
#  'Siddhartha by by Hermann Hesse': 'Siddhartha',
#  'Jude the Obscure by Thomas Hardy': 'Jude the Obscure',
#  'The Turn of the Screw, by Henry James': 'Turn of the Screw',
#  "Uncle Tom's Cabin by Harriet Beecher Stowe": "Uncle Tom's Cabin",
#  'The Complete Works of William Shakespeare King Richard III': 'Richard III',
#  'Walden, by Henry David Thoreau': 'Walden',
#  'The Complete Works of William Shakespeare The Comedy of Errors': 'The Comedy of Errors',
#  'Phaedo by Plato': 'Phaedo',
#  'Meno by Plato': 'Meno',
#  'Les Miserables by Victor Hugo, trans. Isabel F. Hapgood': 'Les Miserables',
#  "Gulliver's Travels by Jonathan Swift": "Gulliver's Travels"}

# %%
#For every book in full text, add corresponding title from df_summaries to 'book_titles' list

book_titles = []
for title in df_texts['title']:
    book_titles.append(fulltext_to_summary[title])

# %%
#Create new column of shorter form titles from df_summaries in df_texts using 'book_titles' list created in last step

df_texts['book_title'] = book_titles

# %%
#Check that new column has been added correctly

df_texts.head(20)
# Out:
#                                                 title  \
# 0                     The Scarlet Letter by Hawthorne
# 1     The Hound of the Baskervilles by A. Conan Doyle
# 2   The Life of Henry VIII by William Shakespeare ...
# 3             Of Human Bondage by W. Somerset Maugham
# 4   The Complete Works of William Shakespeare Cymb...
# 5                             Ivanhoe by Walter Scott
# 6                          My Antonia by Willa Cather
# 7                The Call of the Wild, by Jack London
# 8   The Adventures of Tom Sawyer, Complete by Mark...
# 9                                 Candide by Voltaire
# 10              The Age of Innocence by Edith Wharton
# 11  The Canterbury Tales and Other Poems by Geoffr...
# 12                 Pride and Prejudice by Jane Austen
# 13               Winesburg, Ohio by Sherwood Anderson
# 14  The Adventures of Huckleberry Finn by Mark Twa...
# 15                      The Jungle, by Upton Sinclair
# 16                    Oliver Twist by Charles Dickens
# 17  The Complete Works of William Shakespeare As Y...
# 18                  Madame Bovary by Gustave Flaubert
# 19                        Middlemarch by George Eliot
#
#                                                  text  \
# 0   The Scarlet LetterbyHawthorne\n\n\n\n\n\r\nTHE...
# 1   The Hound of the BaskervillesbyA. Conan Doyle\...
# 2   The Life of Henry VIIIbyWilliam Shakespeare [D...
# 3   Of Human BondagebyW. Somerset Maugham\n\n\n\n\...
# 4   The Complete Works of William Shakespeare Cymb...
# 5   IvanhoebyWalter Scott\n\n\n\n\r\nPrepared by "...
# 6   My AntoniabyWilla Cather\r\n\r\nsoftware or an...
# 7   The Call of the Wild, by Jack London\n\n\n\n\n...
# 8   The Adventures of Tom Sawyer, CompletebyMark T...
# 9   CandidebyVoltaire\r\n\r\neditions, all of whic...
# 10  The Age of InnocencebyEdith Wharton\n\n\n\n\n\...
# 11  The Canterbury Tales and Other PoemsbyGeoffrey...
# 12  Pride and PrejudicebyJane Austen\n\n\n\n\r\nPr...
# 13  Winesburg, OhiobySherwood Anderson\n\n\n\n\n\r...
# 14  The Adventures of Huckleberry FinnbyMark Twain...
# 15  The Jungle, by Upton Sinclair\n\n\n\r\nThe Jun...
# 16  Oliver TwistbyCharles Dickens\n\n\n\n\r\nThis ...
# 17  The Complete Works of William Shakespeare As Y...
# 18  Madame BovarybyGustave Flaubert\n\n\n\n\n\r\nM...
# 19  MiddlemarchbyGeorge Eliot\n\n\n\n\r\nScanned w...
#
#                             book_title
# 0                   The Scarlet Letter
# 1        The Hound of the Baskervilles
# 2                           Henry VIII
# 3                     Of Human Bondage
# 4                            Cymbeline
# 5                              Ivanhoe
# 6                           My Antonia
# 7                 The Call of the Wild
# 8         The Adventures of Tom Sawyer
# 9                              Candide
# 10                The Age of Innocence
# 11                The Canterbury Tales
# 12                 Pride and Prejudice
# 13                     Winesburg, Ohio
# 14  The Adventures of Huckleberry Finn
# 15                          The Jungle
# 16                        Oliver Twist
# 17                      As You Like It
# 18                       Madame Bovary
# 19                         Middlemarch

# %%
#Testing drop of original longer form 'title' column in df_texts

df_texts.drop(columns='title')
# Out:
#                                                  text  \
# 0   The Scarlet LetterbyHawthorne\n\n\n\n\n\r\nTHE...
# 1   The Hound of the BaskervillesbyA. Conan Doyle\...
# 2   The Life of Henry VIIIbyWilliam Shakespeare [D...
# 3   Of Human BondagebyW. Somerset Maugham\n\n\n\n\...
# 4   The Complete Works of William Shakespeare Cymb...
# 5   IvanhoebyWalter Scott\n\n\n\n\r\nPrepared by "...
# 6   My AntoniabyWilla Cather\r\n\r\nsoftware or an...
# 7   The Call of the Wild, by Jack London\n\n\n\n\n...
# 8   The Adventures of Tom Sawyer, CompletebyMark T...
# 9   CandidebyVoltaire\r\n\r\neditions, all of whic...
# 10  The Age of InnocencebyEdith Wharton\n\n\n\n\n\...
# 11  The Canterbury Tales and Other PoemsbyGeoffrey...
# 12  Pride and PrejudicebyJane Austen\n\n\n\n\r\nPr...
# 13  Winesburg, OhiobySherwood Anderson\n\n\n\n\n\r...
# 14  The Adventures of Huckleberry FinnbyMark Twain...
# 15  The Jungle, by Upton Sinclair\n\n\n\r\nThe Jun...
# 16  Oliver TwistbyCharles Dickens\n\n\n\n\r\nThis ...
# 17  The Complete Works of William Shakespeare As Y...
# 18  Madame BovarybyGustave Flaubert\n\n\n\n\n\r\nM...
# 19  MiddlemarchbyGeorge Eliot\n\n\n\n\r\nScanned w...
# 20  A Christmas CarolbyCharles Dickens\n\n\n\n\r\n...
# 21  A Tale of Two Cities, by Charles Dickens [A st...
# 22  The Jew of MaltabyChristopher Marlowe\n\n\n\n\...
# 23  Under the Greenwood TreebyThomas Hardy\r\n\r\n...
# 24  Notes from the Underground, by Feodor Dostoevs...
# 25  Adam BedebyGeorge Eliot  [pseudonym of Mary An...
# 26  The InfernobyHenri Barbusse\n\n\n\n\r\nProduce...
# 27  The Complete Works of William Shakespeare The ...
# 28  An Ideal HusbandbyOscar Wilde\n\n\n\n\n\r\nAn ...
# 29  Crime and PunishmentbyFyodor Dostoevsky\n\n\n\...
# 30  Dante's Inferno [Divine Comedy]\r\n\r\nother e...
# 31  The Complete Works of William Shakespeare The ...
# 32  The Awakening and Selected Short StoriesbyKate...
# 33  The Complete Works of William Shakespeare Twel...
# 34  The Count of Monte CristobyAlexandre Dumas [Pe...
# 35  The Red Badge of CouragebyStephen Crane\n\n\n\...
# 36  The Complete Works of William Shakespeare The ...
# 37  Wuthering HeightsbyEmily Bronte\n\n\n\n\n\r\nW...
# 38  Hard TimesbyCharles Dickens*\n\n\n\n\n\r\nHard...
# 39  Little WomenbyLouisa May Alcott\n\n\n\n\n\n\r\...
# 40  DublinersbyJames Joyce\n\n\n\n\r\nPrepared by ...
# 41  Persuasion, by Jane Austen\n\n\n\n\n\n\r\nPers...
# 42  Bleak HousebyCharles Dickens\n\n\n\n\n\r\nThis...
# 43  Mansfield Park, by Jane Austen (1775-1817)\n\n...
# 44  David CopperfieldbyCharles Dickens\n\n\n\n\n\r...
#
#                             book_title
# 0                   The Scarlet Letter
# 1        The Hound of the Baskervilles
# 2                           Henry VIII
# 3                     Of Human Bondage
# 4                            Cymbeline
# 5                              Ivanhoe
# 6                           My Antonia
# 7                 The Call of the Wild
# 8         The Adventures of Tom Sawyer
# 9                              Candide
# 10                The Age of Innocence
# 11                The Canterbury Tales
# 12                 Pride and Prejudice
# 13                     Winesburg, Ohio
# 14  The Adventures of Huckleberry Finn
# 15                          The Jungle
# 16                        Oliver Twist
# 17                      As You Like It
# 18                       Madame Bovary
# 19                         Middlemarch
# 20                   A Christmas Carol
# 21                A Tale of Two Cities
# 22                    The Jew of Malta
# 23            Under the Greenwood Tree
# 24          Notes from the Underground
# 25                           Adam Bede
# 26                         The Inferno
# 27                   The Winter's Tale
# 28                    An Ideal Husband
# 29                Crime and Punishment
# 30                       Divine Comedy
# 31              Merry Wives of Windsor
# 32                       The Awakening
# 33                       Twelfth Night
# 34           The Count of Monte Cristo
# 35            The Red Badge of Courage
# 36                           King Lear
# 37                   Wuthering Heights
# 38                          Hard Times
# 39                        Little Women
# 40                           Dubliners
# 41                          Persuasion
# 42                         Bleak House
# 43                      Mansfield Park
# 44                   David Copperfield

# %%
#Permanently drop original longer form 'title' column in df_texts

df_texts.drop(columns='title', inplace=True)

# %% [markdown]
# # Match up / Rename columns in two dataframes

# %%
#Testing rename of 'title' column in df_summaries to more specific 'chapter_title'

df_summaries.rename(columns= {'title':'chapter_title'})
# Out:
#                                          chapter_title  \
# 0                                     Ivanhoe: Summary
# 1                      Crito: Novel Summary: Chapter 1
# 2          NovelGuide: Crito: Novel Summary: Chapter 2
# 3          NovelGuide: Crito: Novel Summary: Chapter 3
# 4                    Henry VIII: Summary: The Prologue
# ..                                                 ...
# 857           The Iliad: Novel Summary: Chapters 23-24
# 858  The Hound of the Baskervilles: Novel Summary: ...
# 859  The Hound of the Baskervilles: Novel Summary: ...
# 860  The Hound of the Baskervilles: Novel Summary: ...
# 861  The Hound of the Baskervilles: Novel Summary: ...
#
#                                                   text  \
# 0    Chapter I\n\tThe story is set in England in th...
# 1    In 399 B.C., Athens sought someone to blame fo...
# 2    Crito enters the cell, depressed himself at th...
# 3    In this part of the dialogue, Socrates gets to...
# 4    \n\tThe Prologue enters and explains that he i...
# ..                                                 ...
# 857  Chapter 23: The Greeks finish their mourning f...
# 858   \nNote: All page numbers in this summary and ...
# 859   \nSummary: Mortimer reads to Holmes and Watso...
# 860   \nSummary: Holmes urges Watson to report any ...
# 861   \nSummary: Watson questions Laura Lyons, who ...
#
#                         book_title
# 0                          Ivanhoe
# 1                            Crito
# 2                            Crito
# 3                            Crito
# 4                       Henry VIII
# ..                             ...
# 857                      The Iliad
# 858  The Hound of the Baskervilles
# 859  The Hound of the Baskervilles
# 860  The Hound of the Baskervilles
# 861  The Hound of the Baskervilles
#
# [862 rows x 3 columns]

# %%
#Permanently rename 'title' column in df_summaries to more specific 'chapter_title'

df_summaries.rename(columns= {'title':'chapter_title'}, inplace=True)

# %%
#Check rename and names of other columns in df_summaries

df_summaries.head(2)
# Out:
#                      chapter_title  \
# 0                 Ivanhoe: Summary
# 1  Crito: Novel Summary: Chapter 1
#
#                                                 text book_title
# 0  Chapter I\n\tThe story is set in England in th...    Ivanhoe
# 1  In 399 B.C., Athens sought someone to blame fo...      Crito

# %%
#Check names of columns in df_texts

df_texts.head(2)
# Out:
#                                                 text  \
# 0  The Scarlet LetterbyHawthorne\n\n\n\n\n\r\nTHE...
# 1  The Hound of the BaskervillesbyA. Conan Doyle\...
#
#                       book_title
# 0             The Scarlet Letter
# 1  The Hound of the Baskervilles

# %%
#For clarity, rename 'text in df_summaries to 'chapter_summary' and 'text' in df_texts to 'full_text'

df_summaries.rename(columns={'text':'chapter_summary'}, inplace=True)
df_texts.rename(columns={'text':'full_text'}, inplace=True)

# %%
#Check renamings in df_summaries

df_summaries.head(2)
# Out:
#                      chapter_title  \
# 0                 Ivanhoe: Summary
# 1  Crito: Novel Summary: Chapter 1
#
#                                      chapter_summary book_title
# 0  Chapter I\n\tThe story is set in England in th...    Ivanhoe
# 1  In 399 B.C., Athens sought someone to blame fo...      Crito

# %%
#Check renamings in df_texts

df_texts.head(2)
# Out:
#                                            full_text  \
# 0  The Scarlet LetterbyHawthorne\n\n\n\n\n\r\nTHE...
# 1  The Hound of the BaskervillesbyA. Conan Doyle\...
#
#                       book_title
# 0             The Scarlet Letter
# 1  The Hound of the Baskervilles

# %% [markdown]
# # Filter dataframes to contain same book titles

# %%
#Number of unique book titles in df_texts

len(df_texts)
# Out:
# 45

# %%
#Number of unique book titles in df_summaries

len(df_summaries['book_title'].unique())
# Out:
# 51

# %%
#Create set of unique book titles in df_texts

df_texts_set = set(df_texts['book_title'])
len(df_texts_set)
# Out:
# 45

# %%
#Create set of unique book titles in df_summaries

df_summaries_set = set(df_summaries['book_title'].unique())
len(df_summaries_set)
# Out:
# 51

# %%
#Use set.intersection to find titles in both df_texts and df_summaries sets - 30 titles total

text_summary_titles = df_texts_set.intersection(df_summaries_set)
len(text_summary_titles)
# Out:
# 30

# %%
#In order to create filtered subset of df_summaries only including titles in both df_summaries and df_texts, start with new one-row dataframe containing the first title
# in text_summary_titles (list created above)

df_summaries_filtered = df_summaries[df_summaries['book_title'] == list(text_summary_titles)[0]]

# %%
#For the rest of the titles in text_summary_titles, create one-row data frames with the title's summary data and add to the bottom of the current dataframe

for i in range(1, len(text_summary_titles)):
    df_summaries_filtered = pd.concat([df_summaries_filtered, df_summaries[df_summaries['book_title'] == list(text_summary_titles)[i]]])

# %%
#Check number of titles in new dataframe - should be 30

len(df_summaries_filtered['book_title'].unique())
# Out:
# 30

# %%
#Check size of new summaries dataframe

len(df_summaries_filtered)
# Out:
# 501

# %%
#In order to create filtered subset of df_texts only including titles in both df_summaries and df_texts, start with new one-row dataframe containing the first title
# in text_summary_titles (list created above)

df_texts_filtered = df_texts[df_texts['book_title'] == list(text_summary_titles)[0]]

# %%
#For the rest of the titles in text_summary_titles, create one-row data frames with the title's text data and add to the bottom of the current dataframe

for i in range(1, len(text_summary_titles)):
    df_texts_filtered = pd.concat([df_texts_filtered, df_texts[df_texts['book_title'] == list(text_summary_titles)[i]]])

# %%
#Check number of titles in new dataframe - should be 30

len(df_texts_filtered['book_title'])
# Out:
# 30

# %% [markdown]
# # Check for & address duplicates in summaries data

# %%
#Check for dataframe duplicates - 146 found

df_summaries_filtered.duplicated().sum()
# Out:
# 146

# %%
#Check shape of overall dataframe - a signficant number of rows are duplicates

df_summaries_filtered.shape
# Out:
# (501, 3)

# %%
#Check duplicates specifically in 'chapter_title' column - matches expected value

df_summaries_filtered['chapter_title'].duplicated().sum()
# Out:
# 146

# %% [markdown]
# Dropping duplicates will result in a somewhat significant data loss. However, this seems to be the best option at this point. Including duplicates would cause these texts to have a disproportionate effect when used in models. As noted previously, gathering and continuing to develop and refine models with more data will be a planned future step for this project.

# %%
#Testing drop of all duplicates in dataframe

df_summaries_filtered.drop_duplicates()
# Out:
#                                          chapter_title  \
# 96                      Candide: Summary: Chapters 1-2
# 97                Candide: Novel Summary: Chapters 1-2
# 98                Candide: Novel Summary: Chapters 3-4
# 99                Candide: Novel Summary: Chapters 5-6
# 100               Candide: Novel Summary: Chapters 7-8
# ..                                                 ...
# 681  Winesburg, Ohio: Novel Summary: The Book of th...
# 682  Winesburg, Ohio: Novel Summary: The Philosophe...
# 683  Winesburg, Ohio: Novel Summary: The Strength o...
# 684     Winesburg, Ohio: Novel Summary: The Untold Lie
# 253                         Middlemarch: Novel Summary
#
#                                        chapter_summary       book_title
# 96   Chapter 1\n Voltaire begins his picaresque tal...          Candide
# 97   Chapter 1: Voltaire begins his picaresque tale...          Candide
# 98   Chapter 3\nChapter 3 takes place in the midst ...          Candide
# 99   Chapter 5\nTraveling to Lisbon on a business t...          Candide
# 100  Chapter 7\nThe strange old woman takes Candide...          Candide
# ..                                                 ...              ...
# 681  Summary\n\tAn old writer has a bed that his ca...  Winesburg, Ohio
# 682  The Philosopher\n\tDoctor Parcival is one of t...  Winesburg, Ohio
# 683  The Strength of God\n\tReverend Curtis Hartman...  Winesburg, Ohio
# 684  Summary\n\tRay Pearson, an older farmhand, is ...  Winesburg, Ohio
# 253  Prelude\nSummary\n\tThis is a charming vignett...      Middlemarch
#
# [355 rows x 3 columns]

# %%
#Permanently drop duplicates from dataframe

df_summaries_dup_dropped = df_summaries_filtered.drop_duplicates()

# %%
#Check new shape of dataframe

df_summaries_dup_dropped.shape
# Out:
# (355, 3)

# %% [markdown]
# # Simplify summary chapter titles

# %% [markdown]
# Upon examination of the full list of chapter titles opened in a spearate text editor, it can be seen that almost all of the chapter titles have a format of
# <br>
# -'Book Title': Novel Summary: Chapter 'chapter number(s)'-
# <br>
# <br>
# 'Book Title: Novel Summary: ' will be dropped from each chapter title to simplify chapter designations

# %%
#Check index of current summaries df -  to be used in loop to build simplified chapter titles column

df_summaries_dup_dropped.index
# Out:
# Int64Index([ 96,  97,  98,  99, 100, 101, 102, 103, 104, 105,
#             ...
#             676, 677, 678, 679, 680, 681, 682, 683, 684, 253],
#            dtype='int64', length=355)

# %%
#Testing reset of index 

df_summaries_dup_dropped.reset_index()
# Out:
#      index                                      chapter_title  \
# 0       96                     Candide: Summary: Chapters 1-2
# 1       97               Candide: Novel Summary: Chapters 1-2
# 2       98               Candide: Novel Summary: Chapters 3-4
# 3       99               Candide: Novel Summary: Chapters 5-6
# 4      100               Candide: Novel Summary: Chapters 7-8
# ..     ...                                                ...
# 350    681  Winesburg, Ohio: Novel Summary: The Book of th...
# 351    682  Winesburg, Ohio: Novel Summary: The Philosophe...
# 352    683  Winesburg, Ohio: Novel Summary: The Strength o...
# 353    684     Winesburg, Ohio: Novel Summary: The Untold Lie
# 354    253                         Middlemarch: Novel Summary
#
#                                        chapter_summary       book_title
# 0    Chapter 1\n Voltaire begins his picaresque tal...          Candide
# 1    Chapter 1: Voltaire begins his picaresque tale...          Candide
# 2    Chapter 3\nChapter 3 takes place in the midst ...          Candide
# 3    Chapter 5\nTraveling to Lisbon on a business t...          Candide
# 4    Chapter 7\nThe strange old woman takes Candide...          Candide
# ..                                                 ...              ...
# 350  Summary\n\tAn old writer has a bed that his ca...  Winesburg, Ohio
# 351  The Philosopher\n\tDoctor Parcival is one of t...  Winesburg, Ohio
# 352  The Strength of God\n\tReverend Curtis Hartman...  Winesburg, Ohio
# 353  Summary\n\tRay Pearson, an older farmhand, is ...  Winesburg, Ohio
# 354  Prelude\nSummary\n\tThis is a charming vignett...      Middlemarch
#
# [355 rows x 4 columns]

# %%
#Permanently reset index

df_summaries_dup_dropped.reset_index(inplace=True)

# %%
#Examine df with new index

df_summaries_dup_dropped.head(15)
# Out:
#     index                           chapter_title  \
# 0      96          Candide: Summary: Chapters 1-2
# 1      97    Candide: Novel Summary: Chapters 1-2
# 2      98    Candide: Novel Summary: Chapters 3-4
# 3      99    Candide: Novel Summary: Chapters 5-6
# 4     100    Candide: Novel Summary: Chapters 7-8
# 5     101   Candide: Novel Summary: Chapters 9-10
# 6     102  Candide: Novel Summary: Chapters 11-12
# 7     103  Candide: Novel Summary: Chapters 13-14
# 8     104  Candide: Novel Summary: Chapters 15-16
# 9     105  Candide: Novel Summary: Chapters 17-18
# 10    106  Candide: Novel Summary: Chapters 19-20
# 11    107  Candide: Novel Summary: Chapters 21-22
# 12    108  Candide: Novel Summary: Chapters 23-24
# 13    109  Candide: Novel Summary: Chapters 25-26
# 14    110  Candide: Novel Summary: Chapters 27-28
#
#                                       chapter_summary book_title
# 0   Chapter 1\n Voltaire begins his picaresque tal...    Candide
# 1   Chapter 1: Voltaire begins his picaresque tale...    Candide
# 2   Chapter 3\nChapter 3 takes place in the midst ...    Candide
# 3   Chapter 5\nTraveling to Lisbon on a business t...    Candide
# 4   Chapter 7\nThe strange old woman takes Candide...    Candide
# 5   Chapter 9\nSeeing what he believes to be anoth...    Candide
# 6   Chapter 11\nIn this chapter the old woman begi...    Candide
# 7   Chapter 13\n As the story returns to the prese...    Candide
# 8   Chapter 15\nThe commander, Cunégonde's brother...    Candide
# 9   Chapter 17\n In this chapter the reader is int...    Candide
# 10  Chapter 19\nHaving left Eldorado, Candide and ...    Candide
# 11  Chapter 21\n Finally, Candide and Martin reach...    Candide
# 12  Chapter 23: Now on the way to England, Martin ...    Candide
# 13   \nChapter 25: Now inside the senator's home, ...    Candide
# 14  Chapter 27\n Now boarding the ship, the relent...    Candide

# %%
#Drop original index column

df_summaries_dup_dropped.drop(columns='index', inplace=True)
# Out:
# /var/folders/4l/vc1t1v4j7qd0h8x2x8dt42rw0000gn/T/ipykernel_77394/2116391961.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_summaries_dup_dropped.drop(columns='index', inplace=True)

# %%
#Examine changes to df

df_summaries_dup_dropped.head()
# Out:
#                           chapter_title  \
# 0        Candide: Summary: Chapters 1-2
# 1  Candide: Novel Summary: Chapters 1-2
# 2  Candide: Novel Summary: Chapters 3-4
# 3  Candide: Novel Summary: Chapters 5-6
# 4  Candide: Novel Summary: Chapters 7-8
#
#                                      chapter_summary book_title
# 0  Chapter 1\n Voltaire begins his picaresque tal...    Candide
# 1  Chapter 1: Voltaire begins his picaresque tale...    Candide
# 2  Chapter 3\nChapter 3 takes place in the midst ...    Candide
# 3  Chapter 5\nTraveling to Lisbon on a business t...    Candide
# 4  Chapter 7\nThe strange old woman takes Candide...    Candide

# %%
#For 'chapter_title' column in each row of summaries df, add shortened chapter title to list

shortened_ch_titles = []
for i in df_summaries_dup_dropped.index:
    bk_title = df_summaries_dup_dropped.iloc[i]['book_title']
    shortened_title = df_summaries_dup_dropped.iloc[i]['chapter_title'].replace(f'{bk_title}: Novel Summary: ', '')
    shortened_ch_titles.append(shortened_title)

# %%
#Examine newly created list

shortened_ch_titles[:20]
# Out:
# ['Candide: Summary: Chapters 1-2',
#  'Chapters 1-2',
#  'Chapters 3-4',
#  'Chapters 5-6',
#  'Chapters 7-8',
#  'Chapters 9-10',
#  'Chapters 11-12',
#  'Chapters 13-14',
#  'Chapters 15-16',
#  'Chapters 17-18',
#  'Chapters 19-20',
#  'Chapters 21-22',
#  'Chapters 23-24',
#  'Chapters 25-26',
#  'Chapters 27-28',
#  'The Age of Innocence: Novel Summary',
#  'Chapters 1-3',
#  'Chapters 4-6',
#  'Chapters 7-9',
#  'Chapters 10-12']

# %%
#Used list to add new shortened chapter titles column to summaries df

df_summaries_dup_dropped['chapters'] = shortened_ch_titles
# Out:
# /var/folders/4l/vc1t1v4j7qd0h8x2x8dt42rw0000gn/T/ipykernel_77394/3461041460.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_summaries_dup_dropped['chapters'] = shortened_ch_titles

# %%
#Examine changes to df

df_summaries_dup_dropped.head(15)
# Out:
#                              chapter_title  \
# 0           Candide: Summary: Chapters 1-2
# 1     Candide: Novel Summary: Chapters 1-2
# 2     Candide: Novel Summary: Chapters 3-4
# 3     Candide: Novel Summary: Chapters 5-6
# 4     Candide: Novel Summary: Chapters 7-8
# 5    Candide: Novel Summary: Chapters 9-10
# 6   Candide: Novel Summary: Chapters 11-12
# 7   Candide: Novel Summary: Chapters 13-14
# 8   Candide: Novel Summary: Chapters 15-16
# 9   Candide: Novel Summary: Chapters 17-18
# 10  Candide: Novel Summary: Chapters 19-20
# 11  Candide: Novel Summary: Chapters 21-22
# 12  Candide: Novel Summary: Chapters 23-24
# 13  Candide: Novel Summary: Chapters 25-26
# 14  Candide: Novel Summary: Chapters 27-28
#
#                                       chapter_summary book_title  \
# 0   Chapter 1\n Voltaire begins his picaresque tal...    Candide
# 1   Chapter 1: Voltaire begins his picaresque tale...    Candide
# 2   Chapter 3\nChapter 3 takes place in the midst ...    Candide
# 3   Chapter 5\nTraveling to Lisbon on a business t...    Candide
# 4   Chapter 7\nThe strange old woman takes Candide...    Candide
# 5   Chapter 9\nSeeing what he believes to be anoth...    Candide
# 6   Chapter 11\nIn this chapter the old woman begi...    Candide
# 7   Chapter 13\n As the story returns to the prese...    Candide
# 8   Chapter 15\nThe commander, Cunégonde's brother...    Candide
# 9   Chapter 17\n In this chapter the reader is int...    Candide
# 10  Chapter 19\nHaving left Eldorado, Candide and ...    Candide
# 11  Chapter 21\n Finally, Candide and Martin reach...    Candide
# 12  Chapter 23: Now on the way to England, Martin ...    Candide
# 13   \nChapter 25: Now inside the senator's home, ...    Candide
# 14  Chapter 27\n Now boarding the ship, the relent...    Candide
#
#                           chapters
# 0   Candide: Summary: Chapters 1-2
# 1                     Chapters 1-2
# 2                     Chapters 3-4
# 3                     Chapters 5-6
# 4                     Chapters 7-8
# 5                    Chapters 9-10
# 6                   Chapters 11-12
# 7                   Chapters 13-14
# 8                   Chapters 15-16
# 9                   Chapters 17-18
# 10                  Chapters 19-20
# 11                  Chapters 21-22
# 12                  Chapters 23-24
# 13                  Chapters 25-26
# 14                  Chapters 27-28

# %% [markdown]
# # Export filtered & homogenized dataframes to csv files

# %%
df_texts_filtered.to_csv('./data/working_data/book_texts/full_texts_filtered.csv', index=False)
df_summaries_filtered.to_csv('./data/working_data/book_summaries/summaries_filtered.csv', index=False)

# %% [markdown]
# # Create new dataframe including book titles, chapter titles, chapter summaries, & book full texts (to be used in process of dividing full texts into chapters)

# %%
#For each row in the summaries df, add the corresponding book full text to a list

full_texts = []

for i in df_summaries_dup_dropped.index:
    book = df_summaries_dup_dropped.iloc[i]['book_title']
    full_text = df_texts_filtered[df_texts_filtered['book_title']==book]['full_text']
    full_texts.append(full_text)

# %%
#Create a copy of the most recent edit of the summaries df

summaries_and_fulltexts = df_summaries_dup_dropped.copy(deep=True)

# %%
#Add list of full texts created to 'summaries_and_fulltexts' df as new 'full_text' column

summaries_and_fulltexts['full_text'] = full_texts

# %%
#Examine new dataframe

summaries_and_fulltexts.head()
# Out:
#                           chapter_title  \
# 0        Candide: Summary: Chapters 1-2
# 1  Candide: Novel Summary: Chapters 1-2
# 2  Candide: Novel Summary: Chapters 3-4
# 3  Candide: Novel Summary: Chapters 5-6
# 4  Candide: Novel Summary: Chapters 7-8
#
#                                      chapter_summary book_title  \
# 0  Chapter 1\n Voltaire begins his picaresque tal...    Candide
# 1  Chapter 1: Voltaire begins his picaresque tale...    Candide
# 2  Chapter 3\nChapter 3 takes place in the midst ...    Candide
# 3  Chapter 5\nTraveling to Lisbon on a business t...    Candide
# 4  Chapter 7\nThe strange old woman takes Candide...    Candide
#
#                          chapters  \
# 0  Candide: Summary: Chapters 1-2
# 1                    Chapters 1-2
# 2                    Chapters 3-4
# 3                    Chapters 5-6
# 4                    Chapters 7-8
#
#                                            full_text
# 0  9    CandidebyVoltaire\r\n\r\neditions, all of...
# 1  9    CandidebyVoltaire\r\n\r\neditions, all of...
# 2  9    CandidebyVoltaire\r\n\r\neditions, all of...
# 3  9    CandidebyVoltaire\r\n\r\neditions, all of...
# 4  9    CandidebyVoltaire\r\n\r\neditions, all of...

# %% [markdown]
# # Export summaries & full texts dataframe to csv

# %%
summaries_and_fulltexts.to_csv('./data/working_data/summaries_and_full_texts.csv', index=False)
