# %% [markdown]
# # Imports

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, create_optimizer, PushToHubCallback, pipeline
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tqdm import tqdm
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
import pandas as pd

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Script to load & process data, set up model, fit model, & save model to Hugging Face Hub

# %%
#Load data
data = load_dataset(
    'csv', data_files={
        'train':'./drive/MyDrive/General_Assembly/Capstone_Project/data/training_data.csv',
        'test':'./drive/MyDrive/General_Assembly/Capstone_Project/data/testing_data.csv',
        'validation':'./drive/MyDrive/General_Assembly/Capstone_Project/data/validation_data.csv'
        }
    )

#Laod model & tokenizer
model_checkpoint = 'sshleifer/distilbart-xsum-1-1'
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = TFAutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)

#Process data for modeling
def preprocess_function(text_data):
  model_inputs = tokenizer(
      text_data['chapter_text'], max_length=1024, truncation=True)     
  with tokenizer.as_target_tokenizer():
    labels = tokenizer(
        text_data['chapter_summary'], max_length=1024, truncation=True)   
    model_inputs['labels'] = labels['input_ids']
    return model_inputs
tokenized_data = data.map(preprocess_function)
tokenized_data_features = tokenized_data.remove_columns(
    data['train'].column_names)
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors='tf')
tf_train = tokenized_data_features['train'].to_tf_dataset(
    columns=['input_ids', 'attention_mask', 'labels'],
    collate_fn=data_collator,
    shuffle=True,
    batch_size=1)
tf_validation = tokenized_data_features['validation'].to_tf_dataset(
    columns=['input_ids', 'attention_mask', 'labels'],
    collate_fn=data_collator,
    shuffle=False,
    batch_size=1)
tf_test = tokenized_data_features['test'].to_tf_dataset(
    columns=['input_ids', 'attention_mask', 'labels'],
    collate_fn=data_collator,
    shuffle=False,
    batch_size=1)

#Compile & fit model
num_train_epochs = 25
num_train_steps = len(tf_train) * num_train_epochs
optimizer, schedule = create_optimizer(
    init_lr=5.6e-5,
    num_warmup_steps=0,
    num_train_steps=num_train_steps,
    weight_decay_rate=0.1,)
model.compile(optimizer=optimizer)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
push_to_hub = PushToHubCallback(     #callback to save model to Hugging Face hub
    output_dir='./summary_model', tokenizer=tokenizer, hub_model_id='AnnaR/literature_summarizer')
model_history = model.fit(tf_train, validation_data=tf_validation, callbacks=[early_stop, push_to_hub], epochs=25, verbose=0)
# Out:
# Using custom data configuration default-74d066c3e8549d77
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-74d066c3e8549d77/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/3 [00:00<?, ?it/s]
# All model checkpoint layers were used when initializing TFBartForConditionalGeneration.
#
# All the layers of TFBartForConditionalGeneration were initialized from the model checkpoint at sshleifer/distilbart-xsum-1-1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-74d066c3e8549d77/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-6c6fe7e5e76a28b0.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-74d066c3e8549d77/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-13c913eb270e8082.arrow
#   0%|          | 0/24 [00:00<?, ?ex/s]
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! Please ensure your labels are passed as keys in the input dict so that they are accessible to the model during the forward pass. To disable this behaviour, please pass a loss argument, or explicitly pass loss=None if you do not want your model to compute a loss.
# Cloning https://huggingface.co/AnnaR/literature_summarizer into local empty directory.
# Epoch 11: early stopping
# Upload file tf_model.h5:   0%|          | 32.0k/317M [00:00<?, ?B/s]
# remote: tput: No value for $TERM and no -T specified
# remote: tput: No value for $TERM and no -T specified
# remote: tput: No value for $TERM and no -T specified
# remote: tput: No value for $TERM and no -T specified
# To https://huggingface.co/AnnaR/literature_summarizer
#    26eb539..a6a6f32  main -> main

# %% [markdown]
# # Generate summaries predictions from test data

# %%
#Add reference and model-generated summaries to lists
test_labels = []
test_preds = []

for batch in tqdm(tf_test):
    predictions = model.generate(batch['input_ids'])
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = batch["labels"].numpy()
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    decoded_preds = ["\n".join(sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(sent_tokenize(label.strip())) for label in decoded_labels]
    test_preds.extend(decoded_preds)
    test_labels.extend(decoded_labels)

#Save in dataframe
test_summaries = pd.DataFrame({'reference':test_labels, 'model-generated':test_preds})
# Out:
# 100%|██████████| 59/59 [09:21<00:00,  9.52s/it]

# %% [markdown]
# ## Model-generated Summaries

# %%
test_summaries
# Out:
#                                             reference  \
# 0   Godliness I This is the first in a four-part s...
# 1   Next, the UM uses the analogy of the road to p...
# 2   Duke Frederick finds that Celia, Rosalind, and...
# 3   After the celebration of one day in Rome, Albe...
# 4   5    Getting into the rowboat that the murdere...
# 5   Falstaff has agreed to go to the wood, hoping ...
# 6   Oliver was overjoyed at the news that she woul...
# 7   Believing themselves to be close to freedom no...
# 8   Part2,  He hides the stolen items beneath a ro...
# 9   : Rosalind enters as the boy actor who played ...
# 10  Realizing that he's been in a semi-conscious s...
# 11  Healed by Virgil's forgiveness, Dante moves on...
# 12  I Chapter 1-4 The narrator begins his story in...
# 13  Sir Andrew is convinced that Olivia will never...
# 14  Zosimov is a doctor and friend of Razumikhin.\...
# 15  Oswald carries a message back to Regan from Go...
# 16  In this chapter Huck meets with Mary Jane, one...
# 17  Goneril meets with the steward of her househol...
# 18  For three days in a row there has been more th...
# 19  Henry’s regiment marches to some trenches to r...
# 20  begins by explaining how Jurgis is still young...
# 21  Dante is deeply discouraged by seeing Virgil s...
# 22  Elmer Cowley is the son of Ebenezer Cowley, a ...
# 23  Mercedes goes to the house of the count, disgu...
# 24  Darcy and Fitzwilliam leave Rosings the next m...
# 25  Katherine is sewing with her ladies-in-waiting...
# 26  The scene opens at the court of the Duke Orsin...
# 27  The centaur leaves them on the farther shore o...
# 28  Note: All page numbers in this summary and ana...
# 29  Two of Mr. Sikes cohorts are waiting inside, T...
# 30  Henry makes his way apprehensively to towards ...
# 31  Nancy and Mr. Sikes drag Oliver to another of ...
# 32  In the house of Countess Olivia, her kinsmen S...
# 33  The play opens in a room at the court of King,...
# 34  Fagin was condemned to hang in court and was t...
# 35  Ellen tells Catherine to be quiet, as Joseph i...
# 36  The UM now uses an analogy to make his point.\...
# 37  Outside the court Charles Darnay, Lucie Manett...
# 38  George often goes to see Belle Carpenter, a yo...
# 39  Elizabeth Willard often visited Doctor Reefy i...
# 40  Sir Toby, Sir Andrew, and the Fool are having ...
# 41  Mrs. Dean cleans Heathcliff up and encourages ...
# 42  The UM more clearly focuses his assault on Che...
# 43  As they ran through the fields, Sikes had trie...
# 44  Catherine tells Heathcliff that her father wil...
# 45  Dante wakes up and finds himself "on the brink...
# 46  Lady Olivia tells Sebastian of her love for hi...
# 47  : Mortimer reads to Holmes and Watson an early...
# 48  When he first enters  Circle, Dante sees Minos...
# 49  When Dante and Virgil come to the foot of the ...
# 50  Katherine, who is increasingly emotionally uns...
# 51  Dante tells us the shape of the Eighth Circle;...
# 52  Luzhin is sobered by yesterday's events with D...
# 53  Respectability Wash Williams is a huge, dirty,...
# 54  Jim learns to ride one of his grandparents’ ho...
# 55  Archer and May begin their round of betrothal ...
# 56  The king, leaning on Wolsey's shoulder, thanks...
# 57  Mr. Collins begins to ignore Elizabeth, and hi...
# 58  A sheer mountainside leads down to the Seventh...
#
#                                       model-generated
# 0   In this chapter, Jesse, a farmhouse, has died ...
# 1   In this chapter, the UM has become the first m...
# 2   The Duchess of Cornwall has been told that she...
# 3   Dantes and Dantes arrive at the house of Dante...
# 4   In this chapter, Huck's Jim is saved by a boat...
# 5   Fenton Ford and Mrs.\nPage enters with Falstaf...
# 6   Fagin decides that he wants to go back to his ...
# 7   This scene begins to show Jim on the island of...
# 8   In the search for a man who has been imprisone...
# 9   Duke and Duchess of Cornwall have completed th...
# 10  The next morning, Simonov enters and tells him...
# 11  In this chapter, Orlando, Virgil tells him tha...
# 12  In this chapter, the Fourth Circle, the Old Ma...
# 13  In this chapter, the FABIan, Sir Toby, Sir And...
# 14  Raskolnikov tells Razumikhin that he has been ...
# 15  Edmund and Edmund are sent to a letter to the ...
# 16  : Novel : 2 ›  In this chapter, Miss Manette a...
# 17  Goneril and tells the Duke of Albany that he h...
# 18  Defarge Defarge arrives at the court of Monsie...
# 19  In this chapter, the regiment begins to pull o...
# 20  Jurgis has become a part of a plan to build a ...
# 21  In this chapter, Virgil and Virgil tells him t...
# 22  This is a reporter, George Willard, and he run...
# 23  In this chapter, Monte Cristo's son, Monsieur ...
# 24  Lady Catherine Collins and Collins are invited...
# 25  In the first round of the King Henry II, the k...
# 26  Ospreys and the Duke of Albany, are in connect...
# 27  In this chapter, Dante sees one of the most im...
# 28  Conan Conan Doyle, the Conan Conan Conan, and ...
# 29  Fagin decides that he wants to go back to his ...
# 30  Fagin decides that he wants to go back to his ...
# 31  Fagin decides that he wants to go back to his ...
# 32  Maria Ay and Sir Andrew Aguecheek enter the co...
# 33  The King Garter King Henry enters the play, an...
# 34  In this chapter, the trial of a man accused of...
# 35  Hareton, Hareton and Hareton were killed and i...
# 36  In this chapter, the account of the man who ha...
# 37  Darnay's son, Lucie and Lucie are waiting for ...
# 38  In the first day of the year, the Carpanto sho...
# 39  Elizabeth Reefy's son, John Reefy has become a...
# 40  At the end of the song song song, Sir Andrew, ...
# 41  Heathcliff tells her that she will not be able...
# 42  In this chapter, the UM has become the first m...
# 43  Fagin decides that he wants to go back to his ...
# 44                                : : : Novel : 2 › ›
# 45  Dante speaks to Dante to Dante as Dante's son,...
# 46  Viola enters the house of Lady Olivia, and Ant...
# 47  The Sherlock Holmes and Holmes are in hospital...
# 48  In this chapter, Dante sees Dante and Virgil a...
# 49  Dante sees Virgil and Virgil in the lake, but ...
# 50  Raskolnikov leaves, Sonia, has died aged 86.\n...
# 51  In the Fourth Circle, Dante, Virgil and Virgil...
# 52  Raskolnikov tells Razumikhin that he will go t...
# 53  Winesburg has become a part of his plan to bui...
# 54  In this chapter, the story of Otto Fuchs, a fe...
# 55  Mingott, Mrs Mingott's daughter, who is marrie...
# 56  King Katherine, Katherine, who has been impris...
# 57  Wickham and Elizabeth are invited to visit Wic...
# 58  Dante's sonne, Dante sees Dante's head coach, ...

# %% [markdown]
# # Test pipeline from model saved on Hugging Face

# %%
summarizer = pipeline('summarization', model='AnnaR/literature_summarizer')
# Out:
# All model checkpoint layers were used when initializing TFBartForConditionalGeneration.
#
# All the layers of TFBartForConditionalGeneration were initialized from the model checkpoint at AnnaR/literature_summarizer.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.

# %%
text = data['test']['chapter_text'][10]

# %%
#Reference text
text
# Out:
# 'O and Lermontov\'s MASQUERADE. And all at once I felt horribly ashamed, so ashamed that I stopped the horse, got out of the sledge, and stood still in the snow in the middle of the street. The driver gazed at me, sighing and astonished. What was I to do? I could not go on there--it was evidently stupid, and I could not leave things as they were, because that would seem as though ... Heavens, how could I leave things! And after such insults! "No!" I cried, throwing myself into the sledge again. "It is ordained! It is fate! Drive on, drive on!" And in my impatience I punched the sledge-driver on the back of the neck. "What are you up to? What are you hitting me for?" the peasant shouted, but he whipped up his nag so that it began kicking. The wet snow was falling in big flakes; I unbuttoned myself, regardless of it. I forgot everything else, for I had finally decided on the slap, and felt with horror that it was going to happen NOW, AT ONCE, and that NO FORCE COULD STOP IT. The deserted street lamps gleamed sull'

# %%
model_text = summarizer(text)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (5642 > 1024). Running this sequence through the model will result in indexing errors

# %%
#Generated summary
model_text[0]['summary_text']
# Out:
# " \xa0  The next morning, Mr. Lermontown arrives at the house of the house, and he finds that Mr. Grange, and Mrs. Lernay, and Mr. Gardiner tells him that he would have to be his father's death. He says that he is"
